# %% [markdown]
# # Deploy and monitor a machine learning workflow for Image Classification

# %% [markdown]
# ## Setting up this notebook
#
# Notes about the instance size and kernel setup: this notebook has been tested on
#
# 1. The `Python 3 (Data Science)` kernel
# 2. The `ml.t3.medium` Sagemaker notebook instance

# %%
# Install necessary SDK packages
# !pip install sagemaker

# %% [markdown]
# Import necessary modules

# %%
import boto3
import sagemaker

import os
import tarfile
import requests
import pickle
import random
from zipfile import ZipFile
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\ADMIN\AppData\Local\sagemaker\sagemaker\config.yaml

# %% [markdown]
# ## Data Staging
#
# We'll use a sample dataset called CIFAR to simulate the challenges Scones Unlimited are facing in Image Classification. In order to start working with CIFAR we'll need to:
#
# 1. Extract the data from a hosting service
# 2. Transform it into a usable shape and format
# 3. Load it into a production system
#
# In other words, we're going to do some simple ETL!

# %% [markdown]
# ### 1. Extract the data from the hosting service
#
# In the cell below, define a function `extract_cifar_data` that extracts python version of the CIFAR-100 dataset. The CIFAR dataaset is open source and generously hosted by the University of Toronto at: https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz

# %%
def extract_cifar_data(url, filename="cifar.tar.gz"):
    """A function for extracting the CIFAR-100 dataset and storing it as a gzipped file

    Arguments:
    url      -- the URL where the dataset is hosted
    filename -- the full path where the dataset will be written

    """

    # Todo: request the data from the data url
    # Hint: use `requests.get` method
    r = requests.get(url)
    with open(filename, "wb") as file_context:
        file_context.write(r.content)
    return

# %% [markdown]
# Let's test it out! Run the following cell and check whether a new file `cifar.tar.gz` is created in the file explorer.

# %%
# Create folder to store dataset
data_path = "dataset"
img_path = "img"
filename = "cifar.tar.gz"

if not os.path.exists(data_path):
    os.makedirs(data_path)
if not os.path.exists(os.path.join(data_path, img_path)):
    os.makedirs(os.path.join(data_path, img_path))

# %%
dest_path_file = os.path.join(data_path, filename)
extract_cifar_data("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz", dest_path_file)

# %% [markdown]
# ### 2. Transform the data into a usable shape and format
#
# Clearly, distributing the data as a gzipped archive makes sense for the hosting service! It saves on bandwidth, storage, and it's a widely-used archive format. In fact, it's so widely used that the Python community ships a utility for working with them, `tarfile`, as part of its Standard Library. Execute the following cell to decompress your extracted dataset:

# %%
with tarfile.open(dest_path_file, "r:gz") as tar:
    tar.extractall(data_path)

# %% [markdown]
# A new folder `cifar-100-python` should be created, containing `meta`, `test`, and `train` files. These files are `pickles` and the [CIFAR homepage](https://www.cs.toronto.edu/~kriz/cifar.html) provides a simple script that can be used to load them. We've adapted the script below for you to run:

# %%
with open(os.path.join(data_path, "cifar-100-python", "meta"), "rb") as f:
    dataset_meta = pickle.load(f, encoding='bytes')

with open(os.path.join(data_path, "cifar-100-python", "test"), "rb") as f:
    dataset_test = pickle.load(f, encoding='bytes')

with open(os.path.join(data_path, "cifar-100-python", "train"), "rb") as f:
    dataset_train = pickle.load(f, encoding='bytes')

# %%
# Feel free to explore the datasets

dataset_train.keys()
# Out:
# dict_keys([b'filenames', b'batch_label', b'fine_labels', b'coarse_labels', b'data'])

# %%
dataset_train[b'data'].shape
# Out:
# (50000, 3072)

# %% [markdown]
# As documented on the homepage, `b'data'` contains rows of 3073 unsigned integers, representing three channels (red, green, and blue) for one 32x32 pixel image per row.

# %%
32*32*3
# Out:
# 3072

# %% [markdown]
# For a simple gut-check, let's transform one of our images. Each 1024 items in a row is a channel (red, green, then blue). Each 32 items in the channel are a row in the 32x32 image. Using python, we can stack these channels into a 32x32x3 array, and save it as a PNG file:

# %%
# Each 1024 in a row is a channel (red, green, then blue)
row = dataset_train[b'data'][0]
red, green, blue = row[0:1024], row[1024:2048], row[2048:]

# Each 32 items in the channel are a row in the 32x32 image
red = red.reshape(32,32)
green = green.reshape(32,32)
blue = blue.reshape(32,32)

# Combine the channels into a 32x32x3 image!
combined = np.dstack((red,green,blue))

# %% [markdown]
# For a more concise version, consider the following:

# %%
# All in one:
test_image = np.dstack((
    row[0:1024].reshape(32,32),
    row[1024:2048].reshape(32,32),
    row[2048:].reshape(32,32)
))

# %%
import matplotlib.pyplot as plt
plt.imshow(test_image);

# %% [markdown]
# Looks like a cow! Let's check the label. `dataset_meta` contains label names in order, and `dataset_train` has a list of labels for each row.

# %%
dataset_train[b'fine_labels'][0]
# Out:
# 19

# %% [markdown]
# Our image has a label of `19`, so let's see what the 19th item is in the list of label names.

# %%
print(dataset_meta[b'fine_label_names'][19])
# Out:
# b'cattle'

# %% [markdown]
# Ok! 'cattle' sounds about right. By the way, using the previous two lines we can do:

# %%
n = 0
print(dataset_meta[b'fine_label_names'][dataset_train[b'fine_labels'][n]])
# Out:
# b'cattle'

# %% [markdown]
# Now we know how to check labels, is there a way that we can also check file names? `dataset_train` also contains a `b'filenames'` key. Let's see what we have here:

# %%
print(dataset_train[b'filenames'][0])
# Out:
# b'bos_taurus_s_000507.png'

# %% [markdown]
# "Taurus" is the name of a subspecies of cattle, so this looks like a pretty reasonable filename. To save an image we can also do:

# %%
plt.imsave(os.path.join(data_path, img_path, "file.png"), test_image)

# %% [markdown]
# Your new PNG file should now appear in the file explorer -- go ahead and pop it open to see!
#
# Now that you know how to reshape the images, save them as files, and capture their filenames and labels, let's just capture all the bicycles and motorcycles and save them. Scones Unlimited can use a model that tells these apart to route delivery drivers automatically.
#
# In the following cell, identify the label numbers for Bicycles and Motorcycles:

# %%
np.array(dataset_meta[b'fine_label_names']) # Show labels to get the exact string for matching condition
# Out:
# array([b'apple', b'aquarium_fish', b'baby', b'bear', b'beaver', b'bed',
#        b'bee', b'beetle', b'bicycle', b'bottle', b'bowl', b'boy',
#        b'bridge', b'bus', b'butterfly', b'camel', b'can', b'castle',
#        b'caterpillar', b'cattle', b'chair', b'chimpanzee', b'clock',
#        b'cloud', b'cockroach', b'couch', b'crab', b'crocodile', b'cup',
#        b'dinosaur', b'dolphin', b'elephant', b'flatfish', b'forest',
#        b'fox', b'girl', b'hamster', b'house', b'kangaroo', b'keyboard',
#        b'lamp', b'lawn_mower', b'leopard', b'lion', b'lizard', b'lobster',
#        b'man', b'maple_tree', b'motorcycle', b'mountain', b'mouse',
#        b'mushroom', b'oak_tree', b'orange', b'orchid', b'otter',
#        b'palm_tree', b'pear', b'pickup_truck', b'pine_tree', b'plain',
#        b'plate', b'poppy', b'porcupine', b'possum', b'rabbit', b'raccoon',
#        b'ray', b'road', b'rocket', b'rose', b'sea', b'seal', b'shark',
#        b'shrew', b'skunk', b'skyscraper', b'snail', b'snake', b'spider',
#        b'squirrel', b'streetcar', b'sunflower', b'sweet_pepper', b'table',
#        b'tank', b'telephone', b'television', b'tiger', b'tractor',
#        b'train', b'trout', b'tulip', b'turtle', b'wardrobe', b'whale',
#        b'willow_tree', b'wolf', b'woman', b'worm'], dtype='|S13')

# %%
# Todo: Filter the dataset_train and dataset_meta objects to find the label numbers for Bicycle and Motorcycles

bk_mtbk_lbl_index = []
for i in range (len(dataset_meta[b'fine_label_names'])):
    lbl_name = dataset_meta[b'fine_label_names'][i]
    if  lbl_name == b'bicycle' or lbl_name == b'motorcycle':
        bk_mtbk_lbl_index.append(i)
bk_mtbk_lbl_index # Get the first 5 objects that satisfy the condition
# Out:
# [8, 48]

# %% [markdown]
# Good job! We only need objects with label 8 and 48 -- this drastically simplifies our handling of the data! Below we construct a dataframe for you, and you can safely drop the rows that don't contain observations about bicycles and motorcycles. Fill in the missing lines below to drop all other rows:

# %%
def load_dataset_bk_mtbk(dataset):
    # Initialize the dataframe
    df = pd.DataFrame({
        "filenames": dataset[b'filenames'],
        "labels": dataset[b'fine_labels'],
        "row": range(len(dataset[b'filenames']))
    })
    
    # Drop all rows from df_train where label is not 8 or 48
    df = df[(df["labels"] == 8) | (df["labels"] == 48)]

    # Decode df_train.filenames so they are regular strings
    df["filenames"] = df["filenames"].apply(
        lambda x: x.decode("utf-8")
    )
    return df

# %%
# Construct the dataframe
df_train = load_dataset_bk_mtbk(dataset_train)
df_test = load_dataset_bk_mtbk(dataset_test)

# %%
df_train.shape
# Out:
# (1000, 3)

# %%
df_train.head()
# Out:
#                    filenames  labels  row
# 16         bike_s_000682.png       8   16
# 30         bike_s_000127.png       8   30
# 130       cycle_s_002598.png       8  130
# 152    minibike_s_000824.png      48  152
# 195  motorcycle_s_001856.png      48  195

# %%
df_test.shape
# Out:
# (200, 3)

# %%
df_test.head()
# Out:
#                          filenames  labels  row
# 27        safety_bike_s_000390.png       8   27
# 28               bike_s_000658.png       8   28
# 116        velocipede_s_001744.png       8  116
# 161              bike_s_000643.png       8  161
# 319  ordinary_bicycle_s_000437.png       8  319

# %% [markdown]
# Now that the data is filtered for just our classes, we can save all our images.

# %% [markdown]
# In the previous sections we introduced you to several key snippets of code:
#
# 1. Grabbing the image data:
#
# ```python
# dataset_train[b'data'][0]
# ```
#
# 2. A simple idiom for stacking the image data into the right shape
#
# ```python
# import numpy as np
# np.dstack((
#     row[0:1024].reshape(32,32),
#     row[1024:2048].reshape(32,32),
#     row[2048:].reshape(32,32)
# ))
# ```
#
# 3. A simple `matplotlib` utility for saving images
#
# ```python
# plt.imsave(path+row['filenames'], target)
# ```
#
# Compose these together into a function that saves all the images into the `./test` and `./train` directories. Use the comments in the body of the `save_images` function below to guide your construction of the function:

# %%
import matplotlib.pyplot as plt

def save_images_from_dataset(path, dataset, df):
    if not os.path.exists(path):
        os.makedirs(path)
    for i in range(len(dataset[b'data'])):
        if i in list(df["row"]):
            # Grab the image data in row-major form
            row = dataset[b'data'][i]

            # Consolidated stacking/reshaping from earlier
            target = np.dstack((
                row[0:1024].reshape(32,32),
                row[1024:2048].reshape(32,32),
                row[2048:].reshape(32,32)
            ))

            # Save the image
            plt.imsave(os.path.join(path,  dataset[b'filenames'][i].decode('utf-8')), target)

    # Return any signal data you want for debugging
    return

# %%
## Save all the images that contain "bicycle" or "motorcycle" image
save_images_from_dataset(os.path.join(data_path, "train"), dataset_train, df_train)
save_images_from_dataset(os.path.join(data_path, "test"), dataset_test, df_test)

# %% [markdown]
# ### 3. Load the data
#
# Now we can load the data into S3.
#
# Using the sagemaker SDK grab the current region, execution role, and bucket.

# %%
bucket= 'project02-khangtictoc'
print("Default Bucket: {}".format(bucket))

region = 'us-east-1'
print("AWS Region: {}".format(region))

# [Console] Create role with "AmazonS3FullAccess"
role = 'arn:aws:iam::673115746990:role/Project02-khangtictoc'
print("RoleArn: {}".format(role))
# Out:
# Default Bucket: project02-khangtictoc
# AWS Region: us-east-1
# RoleArn: arn:aws:iam::673115746990:role/Project02-khangtictoc

# %% [markdown]
# With this data we can easily sync your data up into S3!

# %%
os.environ["DEFAULT_S3_BUCKET"] = bucket

# %%
# Configure credentials
# !aws configure set aws_access_key_id ASIAZZOGTGKXLWL4AQN6
# !aws configure set aws_secret_access_key K5UZoY6ccVYdVTJn0Tx1FrDNkx7CgA3ufMkcu3an
# !aws configure set aws_session_token ...

# %%
#!aws s3api create-bucket --bucket %DEFAULT_S3_BUCKET%

# !aws s3 sync ./dataset/train s3://%DEFAULT_S3_BUCKET%/train/
# !aws s3 sync ./dataset/test s3://%DEFAULT_S3_BUCKET%/test/

#!aws s3 sync ./dataset/train s3://${DEFAULT_S3_BUCKET}/train/
#!aws s3 sync ./dataset/test s3://${DEFAULT_S3_BUCKET}/test/
# Out:
# Completed 2.8 KiB/2.7 MiB (4.2 KiB/s) with 1000 file(s) remaining
# upload: dataset\train\bicycle_s_000035.png to s3://project02-khangtictoc/train/bicycle_s_000035.png
# Completed 2.8 KiB/2.7 MiB (4.2 KiB/s) with 999 file(s) remaining
# Completed 5.1 KiB/2.7 MiB (4.3 KiB/s) with 999 file(s) remaining
# upload: dataset\train\bicycle_s_000124.png to s3://project02-khangtictoc/train/bicycle_s_000124.png
# Completed 5.1 KiB/2.7 MiB (4.3 KiB/s) with 998 file(s) remaining
# Completed 7.7 KiB/2.7 MiB (6.4 KiB/s) with 998 file(s) remaining
# upload: dataset\train\bicycle_s_000043.png to s3://project02-khangtictoc/train/bicycle_s_000043.png
# Completed 7.7 KiB/2.7 MiB (6.4 KiB/s) with 997 file(s) remaining
# Completed 10.1 KiB/2.7 MiB (8.2 KiB/s) with 997 file(s) remaining
# upload: dataset\train\bicycle_s_000017.png to s3://project02-khangtictoc/train/bicycle_s_000017.png
# Completed 10.1 KiB/2.7 MiB (8.2 KiB/s) with 996 file(s) remaining
# Completed 12.6 KiB/2.7 MiB (10.3 KiB/s) with 996 file(s) remaining
# upload: dataset\train\bicycle_s_000038.png to s3://project02-khangtictoc/train/bicycle_s_000038.png
# Completed 12.6 KiB/2.7 MiB (10.3 KiB/s) with 995 file(s) remaining
# Completed 15.5 KiB/2.7 MiB (12.5 KiB/s) with 995 file(s) remaining
# upload: dataset\train\bicycle_s_000021.png to s3://project02-khangtictoc/train/bicycle_s_000021.png
# Completed 15.5 KiB/2.7 MiB (12.5 KiB/s) with 994 file(s) remaining
# Completed 18.2 KiB/2.7 MiB (14.0 KiB/s) with 994 file(s) remaining
# upload: dataset\train\bicycle_s_000051.png to s3://project02-khangtictoc/train/bicycle_s_000051.png
# Completed 18.2 KiB/2.7 MiB (14.0 KiB/s) with 993 file(s) remaining
# Completed 20.9 KiB/2.7 MiB (16.1 KiB/s) with 993 file(s) remaining
# upload: dataset\train\bicycle_s_000071.png to s3://project02-khangtictoc/train/bicycle_s_000071.png
# Completed 20.9 KiB/2.7 MiB (16.1 KiB/s) with 992 file(s) remaining
# Completed 23.9 KiB/2.7 MiB (18.4 KiB/s) with 992 file(s) remaining
# upload: dataset\train\bicycle_s_000066.png to s3://project02-khangtictoc/train/bicycle_s_000066.png
# Completed 23.9 KiB/2.7 MiB (18.4 KiB/s) with 991 file(s) remaining
# Completed 26.5 KiB/2.7 MiB (20.2 KiB/s) with 991 file(s) remaining
# upload: dataset\train\bicycle_s_000039.png to s3://project02-khangtictoc/train/bicycle_s_000039.png
# Completed 26.5 KiB/2.7 MiB (20.2 KiB/s) with 990 file(s) remaining
# Completed 29.3 KiB/2.7 MiB (21.8 KiB/s) with 990 file(s) remaining
# upload: dataset\train\bicycle_s_000099.png to s3://project02-khangtictoc/train/bicycle_s_000099.png
# Completed 29.3 KiB/2.7 MiB (21.8 KiB/s) with 989 file(s) remaining
# Completed 32.0 KiB/2.7 MiB (18.5 KiB/s) with 989 file(s) remaining
# upload: dataset\train\bicycle_s_000137.png to s3://project02-khangtictoc/train/bicycle_s_000137.png
# Completed 32.0 KiB/2.7 MiB (18.5 KiB/s) with 988 file(s) remaining
# Completed 34.8 KiB/2.7 MiB (20.1 KiB/s) with 988 file(s) remaining
# upload: dataset\train\bicycle_s_000147.png to s3://project02-khangtictoc/train/bicycle_s_000147.png
# Completed 34.8 KiB/2.7 MiB (20.1 KiB/s) with 987 file(s) remaining
# Completed 37.3 KiB/2.7 MiB (21.3 KiB/s) with 987 file(s) remaining
# upload: dataset\train\bicycle_s_000156.png to s3://project02-khangtictoc/train/bicycle_s_000156.png
# Completed 37.3 KiB/2.7 MiB (21.3 KiB/s) with 986 file(s) remaining
# Completed 40.1 KiB/2.7 MiB (22.8 KiB/s) with 986 file(s) remaining
# upload: dataset\train\bicycle_s_000149.png to s3://project02-khangtictoc/train/bicycle_s_000149.png
# Completed 40.1 KiB/2.7 MiB (22.8 KiB/s) with 985 file(s) remaining
# Completed 42.9 KiB/2.7 MiB (24.1 KiB/s) with 985 file(s) remaining
# upload: dataset\train\bicycle_s_000159.png to s3://project02-khangtictoc/train/bicycle_s_000159.png
# Completed 42.9 KiB/2.7 MiB (24.1 KiB/s) with 984 file(s) remaining
# Completed 45.5 KiB/2.7 MiB (24.8 KiB/s) with 984 file(s) remaining
# upload: dataset\train\bicycle_s_000231.png to s3://project02-khangtictoc/train/bicycle_s_000231.png
# Completed 45.5 KiB/2.7 MiB (24.8 KiB/s) with 983 file(s) remaining
# Completed 48.1 KiB/2.7 MiB (26.1 KiB/s) with 983 file(s) remaining
# upload: dataset\train\bicycle_s_000243.png to s3://project02-khangtictoc/train/bicycle_s_000243.png
# Completed 48.1 KiB/2.7 MiB (26.1 KiB/s) with 982 file(s) remaining
# Completed 50.8 KiB/2.7 MiB (27.4 KiB/s) with 982 file(s) remaining
# upload: dataset\train\bicycle_s_000235.png to s3://project02-khangtictoc/train/bicycle_s_000235.png
# Completed 50.8 KiB/2.7 MiB (27.4 KiB/s) with 981 file(s) remaining
# Completed 53.8 KiB/2.7 MiB (28.8 KiB/s) with 981 file(s) remaining
# upload: dataset\train\bicycle_s_000180.png to s3://project02-khangtictoc/train/bicycle_s_000180.png
# Completed 53.8 KiB/2.7 MiB (28.8 KiB/s) with 980 file(s) remaining
# Completed 56.3 KiB/2.7 MiB (29.7 KiB/s) with 980 file(s) remaining
# upload: dataset\train\bicycle_s_000279.png to s3://project02-khangtictoc/train/bicycle_s_000279.png
# Completed 56.3 KiB/2.7 MiB (29.7 KiB/s) with 979 file(s) remaining
# Completed 58.6 KiB/2.7 MiB (25.9 KiB/s) with 979 file(s) remaining
# upload: dataset\train\bicycle_s_000282.png to s3://project02-khangtictoc/train/bicycle_s_000282.png
# Completed 58.6 KiB/2.7 MiB (25.9 KiB/s) with 978 file(s) remaining
# Completed 61.5 KiB/2.7 MiB (27.2 KiB/s) with 978 file(s) remaining
# upload: dataset\train\bicycle_s_000314.png to s3://project02-khangtictoc/train/bicycle_s_000314.png
# Completed 61.5 KiB/2.7 MiB (27.2 KiB/s) with 977 file(s) remaining
# Completed 64.3 KiB/2.7 MiB (28.2 KiB/s) with 977 file(s) remaining
# upload: dataset\train\bicycle_s_000369.png to s3://project02-khangtictoc/train/bicycle_s_000369.png
# Completed 64.3 KiB/2.7 MiB (28.2 KiB/s) with 976 file(s) remaining
# Completed 66.9 KiB/2.7 MiB (29.2 KiB/s) with 976 file(s) remaining
# upload: dataset\train\bicycle_s_000371.png to s3://project02-khangtictoc/train/bicycle_s_000371.png
# Completed 66.9 KiB/2.7 MiB (29.2 KiB/s) with 975 file(s) remaining
# Completed 69.5 KiB/2.7 MiB (30.0 KiB/s) with 975 file(s) remaining
# upload: dataset\train\bicycle_s_000392.png to s3://project02-khangtictoc/train/bicycle_s_000392.png
# Completed 69.5 KiB/2.7 MiB (30.0 KiB/s) with 974 file(s) remaining
# Completed 72.6 KiB/2.7 MiB (30.6 KiB/s) with 974 file(s) remaining
# upload: dataset\train\bicycle_s_000396.png to s3://project02-khangtictoc/train/bicycle_s_000396.png
# Completed 72.6 KiB/2.7 MiB (30.6 KiB/s) with 973 file(s) remaining
# Completed 75.4 KiB/2.7 MiB (31.7 KiB/s) with 973 file(s) remaining
# upload: dataset\train\bicycle_s_000399.png to s3://project02-khangtictoc/train/bicycle_s_000399.png
# Completed 75.4 KiB/2.7 MiB (31.7 KiB/s) with 972 file(s) remaining
# Completed 78.0 KiB/2.7 MiB (32.7 KiB/s) with 972 file(s) remaining
# upload: dataset\train\bicycle_s_000408.png to s3://project02-khangtictoc/train/bicycle_s_000408.png
# Completed 78.0 KiB/2.7 MiB (32.7 KiB/s) with 971 file(s) remaining
# Completed 80.5 KiB/2.7 MiB (33.6 KiB/s) with 971 file(s) remaining
# upload: dataset\train\bicycle_s_000435.png to s3://project02-khangtictoc/train/bicycle_s_000435.png
# Completed 80.5 KiB/2.7 MiB (33.6 KiB/s) with 970 file(s) remaining
# Completed 83.1 KiB/2.7 MiB (34.0 KiB/s) with 970 file(s) remaining
# upload: dataset\train\bicycle_s_000437.png to s3://project02-khangtictoc/train/bicycle_s_000437.png
# Completed 83.1 KiB/2.7 MiB (34.0 KiB/s) with 969 file(s) remaining
# Completed 85.9 KiB/2.7 MiB (30.8 KiB/s) with 969 file(s) remaining
# Completed 88.8 KiB/2.7 MiB (31.8 KiB/s) with 969 file(s) remaining
# upload: dataset\train\bicycle_s_000467.png to s3://project02-khangtictoc/train/bicycle_s_000467.png
# Completed 88.8 KiB/2.7 MiB (31.8 KiB/s) with 968 file(s) remaining
# upload: dataset\train\bicycle_s_000463.png to s3://project02-khangtictoc/train/bicycle_s_000463.png
# Completed 88.8 KiB/2.7 MiB (31.8 KiB/s) with 967 file(s) remaining
# Completed 90.9 KiB/2.7 MiB (32.5 KiB/s) with 967 file(s) remaining
# upload: dataset\train\bicycle_s_000491.png to s3://project02-khangtictoc/train/bicycle_s_000491.png
# Completed 90.9 KiB/2.7 MiB (32.5 KiB/s) with 966 file(s) remaining
# Completed 93.4 KiB/2.7 MiB (33.0 KiB/s) with 966 file(s) remaining
# upload: dataset\train\bicycle_s_000522.png to s3://project02-khangtictoc/train/bicycle_s_000522.png
# Completed 93.4 KiB/2.7 MiB (33.0 KiB/s) with 965 file(s) remaining
# Completed 95.5 KiB/2.7 MiB (33.2 KiB/s) with 965 file(s) remaining
# upload: dataset\train\bicycle_s_000536.png to s3://project02-khangtictoc/train/bicycle_s_000536.png
# Completed 95.5 KiB/2.7 MiB (33.2 KiB/s) with 964 file(s) remaining
# Completed 98.6 KiB/2.7 MiB (32.9 KiB/s) with 964 file(s) remaining
# upload: dataset\train\bicycle_s_000546.png to s3://project02-khangtictoc/train/bicycle_s_000546.png
# Completed 98.6 KiB/2.7 MiB (32.9 KiB/s) with 963 file(s) remaining
# Completed 101.5 KiB/2.7 MiB (33.8 KiB/s) with 963 file(s) remaining
# upload: dataset\train\bicycle_s_000569.png to s3://project02-khangtictoc/train/bicycle_s_000569.png
# Completed 101.5 KiB/2.7 MiB (33.8 KiB/s) with 962 file(s) remaining
# Completed 104.2 KiB/2.7 MiB (34.7 KiB/s) with 962 file(s) remaining
# Completed 106.9 KiB/2.7 MiB (35.6 KiB/s) with 962 file(s) remaining
# upload: dataset\train\bicycle_s_000537.png to s3://project02-khangtictoc/train/bicycle_s_000537.png
# Completed 106.9 KiB/2.7 MiB (35.6 KiB/s) with 961 file(s) remaining
# upload: dataset\train\bicycle_s_000561.png to s3://project02-khangtictoc/train/bicycle_s_000561.png
# Completed 106.9 KiB/2.7 MiB (35.6 KiB/s) with 960 file(s) remaining
# Completed 109.3 KiB/2.7 MiB (36.4 KiB/s) with 960 file(s) remaining
# upload: dataset\train\bicycle_s_000667.png to s3://project02-khangtictoc/train/bicycle_s_000667.png
# Completed 109.3 KiB/2.7 MiB (36.4 KiB/s) with 959 file(s) remaining
# Completed 112.2 KiB/2.7 MiB (31.1 KiB/s) with 959 file(s) remaining
# Completed 114.9 KiB/2.7 MiB (31.8 KiB/s) with 959 file(s) remaining
# upload: dataset\train\bicycle_s_000781.png to s3://project02-khangtictoc/train/bicycle_s_000781.png
# Completed 114.9 KiB/2.7 MiB (31.8 KiB/s) with 958 file(s) remaining
# Completed 117.7 KiB/2.7 MiB (32.6 KiB/s) with 958 file(s) remaining
# upload: dataset\train\bicycle_s_000753.png to s3://project02-khangtictoc/train/bicycle_s_000753.png
# Completed 117.7 KiB/2.7 MiB (32.6 KiB/s) with 957 file(s) remaining
# Completed 120.6 KiB/2.7 MiB (33.4 KiB/s) with 957 file(s) remaining
# Completed 123.3 KiB/2.7 MiB (34.1 KiB/s) with 957 file(s) remaining
# upload: dataset\train\bicycle_s_000759.png to s3://project02-khangtictoc/train/bicycle_s_000759.png
# Completed 123.3 KiB/2.7 MiB (34.1 KiB/s) with 956 file(s) remaining
# Completed 126.2 KiB/2.7 MiB (34.9 KiB/s) with 956 file(s) remaining
# upload: dataset\train\bicycle_s_000775.png to s3://project02-khangtictoc/train/bicycle_s_000775.png
# Completed 126.2 KiB/2.7 MiB (34.9 KiB/s) with 955 file(s) remaining
# Completed 129.0 KiB/2.7 MiB (35.7 KiB/s) with 955 file(s) remaining
# upload: dataset\train\bicycle_s_000782.png to s3://project02-khangtictoc/train/bicycle_s_000782.png
# Completed 129.0 KiB/2.7 MiB (35.7 KiB/s) with 954 file(s) remaining
# Completed 131.8 KiB/2.7 MiB (36.4 KiB/s) with 954 file(s) remaining
# upload: dataset\train\bicycle_s_000778.png to s3://project02-khangtictoc/train/bicycle_s_000778.png
# Completed 131.8 KiB/2.7 MiB (36.4 KiB/s) with 953 file(s) remaining
# upload: dataset\train\bicycle_s_000774.png to s3://project02-khangtictoc/train/bicycle_s_000774.png
# Completed 131.8 KiB/2.7 MiB (36.4 KiB/s) with 952 file(s) remaining
# upload: dataset\train\bicycle_s_000668.png to s3://project02-khangtictoc/train/bicycle_s_000668.png
# Completed 131.8 KiB/2.7 MiB (36.4 KiB/s) with 951 file(s) remaining
# Completed 134.6 KiB/2.7 MiB (37.0 KiB/s) with 951 file(s) remaining
# upload: dataset\train\bicycle_s_000785.png to s3://project02-khangtictoc/train/bicycle_s_000785.png
# Completed 134.6 KiB/2.7 MiB (37.0 KiB/s) with 950 file(s) remaining
# Completed 137.1 KiB/2.7 MiB (34.1 KiB/s) with 950 file(s) remaining
# upload: dataset\train\bicycle_s_000723.png to s3://project02-khangtictoc/train/bicycle_s_000723.png
# Completed 137.1 KiB/2.7 MiB (34.1 KiB/s) with 949 file(s) remaining
# Completed 139.7 KiB/2.7 MiB (31.8 KiB/s) with 949 file(s) remaining
# upload: dataset\train\bicycle_s_000996.png to s3://project02-khangtictoc/train/bicycle_s_000996.png
# Completed 139.7 KiB/2.7 MiB (31.8 KiB/s) with 948 file(s) remaining
# Completed 142.3 KiB/2.7 MiB (32.4 KiB/s) with 948 file(s) remaining
# upload: dataset\train\bicycle_s_000986.png to s3://project02-khangtictoc/train/bicycle_s_000986.png
# Completed 142.3 KiB/2.7 MiB (32.4 KiB/s) with 947 file(s) remaining
# Completed 145.1 KiB/2.7 MiB (33.0 KiB/s) with 947 file(s) remaining
# Completed 148.0 KiB/2.7 MiB (33.7 KiB/s) with 947 file(s) remaining
# upload: dataset\train\bicycle_s_000861.png to s3://project02-khangtictoc/train/bicycle_s_000861.png
# Completed 148.0 KiB/2.7 MiB (33.7 KiB/s) with 946 file(s) remaining
# Completed 150.8 KiB/2.7 MiB (34.3 KiB/s) with 946 file(s) remaining
# upload: dataset\train\bicycle_s_001002.png to s3://project02-khangtictoc/train/bicycle_s_001002.png
# Completed 150.8 KiB/2.7 MiB (34.3 KiB/s) with 945 file(s) remaining
# upload: dataset\train\bicycle_s_001111.png to s3://project02-khangtictoc/train/bicycle_s_001111.png
# Completed 150.8 KiB/2.7 MiB (34.3 KiB/s) with 944 file(s) remaining
# Completed 153.7 KiB/2.7 MiB (35.0 KiB/s) with 944 file(s) remaining
# Completed 156.3 KiB/2.7 MiB (35.6 KiB/s) with 944 file(s) remaining
# Completed 158.8 KiB/2.7 MiB (36.1 KiB/s) with 944 file(s) remaining
# upload: dataset\train\bicycle_s_000951.png to s3://project02-khangtictoc/train/bicycle_s_000951.png
# Completed 158.8 KiB/2.7 MiB (36.1 KiB/s) with 943 file(s) remaining
# upload: dataset\train\bicycle_s_000822.png to s3://project02-khangtictoc/train/bicycle_s_000822.png
# Completed 158.8 KiB/2.7 MiB (36.1 KiB/s) with 942 file(s) remaining
# upload: dataset\train\bicycle_s_000829.png to s3://project02-khangtictoc/train/bicycle_s_000829.png
# Completed 158.8 KiB/2.7 MiB (36.1 KiB/s) with 941 file(s) remaining
# Completed 161.7 KiB/2.7 MiB (36.8 KiB/s) with 941 file(s) remaining
# upload: dataset\train\bicycle_s_000978.png to s3://project02-khangtictoc/train/bicycle_s_000978.png
# Completed 161.7 KiB/2.7 MiB (36.8 KiB/s) with 940 file(s) remaining
# Completed 164.4 KiB/2.7 MiB (34.9 KiB/s) with 940 file(s) remaining
# upload: dataset\train\bicycle_s_001168.png to s3://project02-khangtictoc/train/bicycle_s_001168.png
# Completed 164.4 KiB/2.7 MiB (34.9 KiB/s) with 939 file(s) remaining
# Completed 167.2 KiB/2.7 MiB (33.7 KiB/s) with 939 file(s) remaining
# upload: dataset\train\bicycle_s_001338.png to s3://project02-khangtictoc/train/bicycle_s_001338.png
# Completed 167.2 KiB/2.7 MiB (33.7 KiB/s) with 938 file(s) remaining
# Completed 170.0 KiB/2.7 MiB (34.2 KiB/s) with 938 file(s) remaining
# upload: dataset\train\bicycle_s_001348.png to s3://project02-khangtictoc/train/bicycle_s_001348.png
# Completed 170.0 KiB/2.7 MiB (34.2 KiB/s) with 937 file(s) remaining
# Completed 172.7 KiB/2.7 MiB (34.8 KiB/s) with 937 file(s) remaining
# upload: dataset\train\bicycle_s_001245.png to s3://project02-khangtictoc/train/bicycle_s_001245.png
# Completed 172.7 KiB/2.7 MiB (34.8 KiB/s) with 936 file(s) remaining
# Completed 175.5 KiB/2.7 MiB (35.3 KiB/s) with 936 file(s) remaining
# upload: dataset\train\bicycle_s_001203.png to s3://project02-khangtictoc/train/bicycle_s_001203.png
# Completed 175.5 KiB/2.7 MiB (35.3 KiB/s) with 935 file(s) remaining
# Completed 177.8 KiB/2.7 MiB (35.8 KiB/s) with 935 file(s) remaining
# upload: dataset\train\bicycle_s_001205.png to s3://project02-khangtictoc/train/bicycle_s_001205.png
# Completed 177.8 KiB/2.7 MiB (35.8 KiB/s) with 934 file(s) remaining
# Completed 180.6 KiB/2.7 MiB (36.3 KiB/s) with 934 file(s) remaining
# upload: dataset\train\bicycle_s_001174.png to s3://project02-khangtictoc/train/bicycle_s_001174.png
# Completed 180.6 KiB/2.7 MiB (36.3 KiB/s) with 933 file(s) remaining
# Completed 183.3 KiB/2.7 MiB (36.9 KiB/s) with 933 file(s) remaining
# upload: dataset\train\bicycle_s_001228.png to s3://project02-khangtictoc/train/bicycle_s_001228.png
# Completed 183.3 KiB/2.7 MiB (36.9 KiB/s) with 932 file(s) remaining
# Completed 186.0 KiB/2.7 MiB (37.3 KiB/s) with 932 file(s) remaining
# upload: dataset\train\bicycle_s_001388.png to s3://project02-khangtictoc/train/bicycle_s_001388.png
# Completed 186.0 KiB/2.7 MiB (37.3 KiB/s) with 931 file(s) remaining
# Completed 188.6 KiB/2.7 MiB (37.8 KiB/s) with 931 file(s) remaining
# upload: dataset\train\bicycle_s_001247.png to s3://project02-khangtictoc/train/bicycle_s_001247.png
# Completed 188.6 KiB/2.7 MiB (37.8 KiB/s) with 930 file(s) remaining
# Completed 191.3 KiB/2.7 MiB (36.3 KiB/s) with 930 file(s) remaining
# upload: dataset\train\bicycle_s_001402.png to s3://project02-khangtictoc/train/bicycle_s_001402.png
# Completed 191.3 KiB/2.7 MiB (36.3 KiB/s) with 929 file(s) remaining
# Completed 194.2 KiB/2.7 MiB (35.3 KiB/s) with 929 file(s) remaining
# upload: dataset\train\bicycle_s_001409.png to s3://project02-khangtictoc/train/bicycle_s_001409.png
# Completed 194.2 KiB/2.7 MiB (35.3 KiB/s) with 928 file(s) remaining
# Completed 197.0 KiB/2.7 MiB (35.8 KiB/s) with 928 file(s) remaining
# Completed 199.7 KiB/2.7 MiB (36.2 KiB/s) with 928 file(s) remaining
# Completed 202.3 KiB/2.7 MiB (36.7 KiB/s) with 928 file(s) remaining
# upload: dataset\train\bicycle_s_001569.png to s3://project02-khangtictoc/train/bicycle_s_001569.png
# Completed 202.3 KiB/2.7 MiB (36.7 KiB/s) with 927 file(s) remaining
# upload: dataset\train\bicycle_s_001448.png to s3://project02-khangtictoc/train/bicycle_s_001448.png
# Completed 202.3 KiB/2.7 MiB (36.7 KiB/s) with 926 file(s) remaining
# upload: dataset\train\bicycle_s_001470.png to s3://project02-khangtictoc/train/bicycle_s_001470.png
# Completed 202.3 KiB/2.7 MiB (36.7 KiB/s) with 925 file(s) remaining
# Completed 205.1 KiB/2.7 MiB (37.2 KiB/s) with 925 file(s) remaining
# upload: dataset\train\bicycle_s_001411.png to s3://project02-khangtictoc/train/bicycle_s_001411.png
# Completed 205.1 KiB/2.7 MiB (37.2 KiB/s) with 924 file(s) remaining
# Completed 207.7 KiB/2.7 MiB (37.6 KiB/s) with 924 file(s) remaining
# upload: dataset\train\bicycle_s_001554.png to s3://project02-khangtictoc/train/bicycle_s_001554.png
# Completed 207.7 KiB/2.7 MiB (37.6 KiB/s) with 923 file(s) remaining
# Completed 210.6 KiB/2.7 MiB (38.0 KiB/s) with 923 file(s) remaining
# upload: dataset\train\bicycle_s_001583.png to s3://project02-khangtictoc/train/bicycle_s_001583.png
# Completed 210.6 KiB/2.7 MiB (38.0 KiB/s) with 922 file(s) remaining
# Completed 213.1 KiB/2.7 MiB (38.4 KiB/s) with 922 file(s) remaining
# upload: dataset\train\bicycle_s_001642.png to s3://project02-khangtictoc/train/bicycle_s_001642.png
# Completed 213.1 KiB/2.7 MiB (38.4 KiB/s) with 921 file(s) remaining
# Completed 215.7 KiB/2.7 MiB (38.8 KiB/s) with 921 file(s) remaining
# upload: dataset\train\bicycle_s_001452.png to s3://project02-khangtictoc/train/bicycle_s_001452.png
# Completed 215.7 KiB/2.7 MiB (38.8 KiB/s) with 920 file(s) remaining
# Completed 218.7 KiB/2.7 MiB (37.7 KiB/s) with 920 file(s) remaining
# upload: dataset\train\bicycle_s_001663.png to s3://project02-khangtictoc/train/bicycle_s_001663.png
# Completed 218.7 KiB/2.7 MiB (37.7 KiB/s) with 919 file(s) remaining
# Completed 221.6 KiB/2.7 MiB (36.8 KiB/s) with 919 file(s) remaining
# upload: dataset\train\bicycle_s_001673.png to s3://project02-khangtictoc/train/bicycle_s_001673.png
# Completed 221.6 KiB/2.7 MiB (36.8 KiB/s) with 918 file(s) remaining
# Completed 224.5 KiB/2.7 MiB (37.2 KiB/s) with 918 file(s) remaining
# upload: dataset\train\bicycle_s_001688.png to s3://project02-khangtictoc/train/bicycle_s_001688.png
# Completed 224.5 KiB/2.7 MiB (37.2 KiB/s) with 917 file(s) remaining
# Completed 227.1 KiB/2.7 MiB (37.6 KiB/s) with 917 file(s) remaining
# upload: dataset\train\bicycle_s_001687.png to s3://project02-khangtictoc/train/bicycle_s_001687.png
# Completed 227.1 KiB/2.7 MiB (37.6 KiB/s) with 916 file(s) remaining
# Completed 229.5 KiB/2.7 MiB (38.0 KiB/s) with 916 file(s) remaining
# upload: dataset\train\bicycle_s_001681.png to s3://project02-khangtictoc/train/bicycle_s_001681.png
# Completed 229.5 KiB/2.7 MiB (38.0 KiB/s) with 915 file(s) remaining
# Completed 232.4 KiB/2.7 MiB (38.4 KiB/s) with 915 file(s) remaining
# upload: dataset\train\bicycle_s_001679.png to s3://project02-khangtictoc/train/bicycle_s_001679.png
# Completed 232.4 KiB/2.7 MiB (38.4 KiB/s) with 914 file(s) remaining
# Completed 235.2 KiB/2.7 MiB (38.8 KiB/s) with 914 file(s) remaining
# upload: dataset\train\bicycle_s_001693.png to s3://project02-khangtictoc/train/bicycle_s_001693.png
# Completed 235.2 KiB/2.7 MiB (38.8 KiB/s) with 913 file(s) remaining
# Completed 237.9 KiB/2.7 MiB (39.0 KiB/s) with 913 file(s) remaining
# upload: dataset\train\bicycle_s_001748.png to s3://project02-khangtictoc/train/bicycle_s_001748.png
# Completed 237.9 KiB/2.7 MiB (39.0 KiB/s) with 912 file(s) remaining
# Completed 240.5 KiB/2.7 MiB (39.4 KiB/s) with 912 file(s) remaining
# upload: dataset\train\bicycle_s_001757.png to s3://project02-khangtictoc/train/bicycle_s_001757.png
# Completed 240.5 KiB/2.7 MiB (39.4 KiB/s) with 911 file(s) remaining
# Completed 243.3 KiB/2.7 MiB (39.6 KiB/s) with 911 file(s) remaining
# upload: dataset\train\bicycle_s_001814.png to s3://project02-khangtictoc/train/bicycle_s_001814.png
# Completed 243.3 KiB/2.7 MiB (39.6 KiB/s) with 910 file(s) remaining
# Completed 245.8 KiB/2.7 MiB (38.8 KiB/s) with 910 file(s) remaining
# upload: dataset\train\bicycle_s_001904.png to s3://project02-khangtictoc/train/bicycle_s_001904.png
# Completed 245.8 KiB/2.7 MiB (38.8 KiB/s) with 909 file(s) remaining
# Completed 248.6 KiB/2.7 MiB (37.9 KiB/s) with 909 file(s) remaining
# upload: dataset\train\bicycle_s_001928.png to s3://project02-khangtictoc/train/bicycle_s_001928.png
# Completed 248.6 KiB/2.7 MiB (37.9 KiB/s) with 908 file(s) remaining
# Completed 251.6 KiB/2.7 MiB (38.4 KiB/s) with 908 file(s) remaining
# upload: dataset\train\bicycle_s_001956.png to s3://project02-khangtictoc/train/bicycle_s_001956.png
# Completed 251.6 KiB/2.7 MiB (38.4 KiB/s) with 907 file(s) remaining
# Completed 254.5 KiB/2.7 MiB (38.7 KiB/s) with 907 file(s) remaining
# upload: dataset\train\bicycle_s_002012.png to s3://project02-khangtictoc/train/bicycle_s_002012.png
# Completed 254.5 KiB/2.7 MiB (38.7 KiB/s) with 906 file(s) remaining
# Completed 257.0 KiB/2.7 MiB (39.0 KiB/s) with 906 file(s) remaining
# upload: dataset\train\bicycle_s_002029.png to s3://project02-khangtictoc/train/bicycle_s_002029.png
# Completed 257.0 KiB/2.7 MiB (39.0 KiB/s) with 905 file(s) remaining
# Completed 259.8 KiB/2.7 MiB (39.4 KiB/s) with 905 file(s) remaining
# upload: dataset\train\bicycle_s_002005.png to s3://project02-khangtictoc/train/bicycle_s_002005.png
# Completed 259.8 KiB/2.7 MiB (39.4 KiB/s) with 904 file(s) remaining
# Completed 262.4 KiB/2.7 MiB (39.7 KiB/s) with 904 file(s) remaining
# upload: dataset\train\bicycle_s_002049.png to s3://project02-khangtictoc/train/bicycle_s_002049.png
# Completed 262.4 KiB/2.7 MiB (39.7 KiB/s) with 903 file(s) remaining
# Completed 265.2 KiB/2.7 MiB (39.9 KiB/s) with 903 file(s) remaining
# upload: dataset\train\bicycle_s_002100.png to s3://project02-khangtictoc/train/bicycle_s_002100.png
# Completed 265.2 KiB/2.7 MiB (39.9 KiB/s) with 902 file(s) remaining
# Completed 267.7 KiB/2.7 MiB (40.3 KiB/s) with 902 file(s) remaining
# upload: dataset\train\bicycle_s_002129.png to s3://project02-khangtictoc/train/bicycle_s_002129.png
# Completed 267.7 KiB/2.7 MiB (40.3 KiB/s) with 901 file(s) remaining
# Completed 270.3 KiB/2.7 MiB (40.4 KiB/s) with 901 file(s) remaining
# upload: dataset\train\bicycle_s_002132.png to s3://project02-khangtictoc/train/bicycle_s_002132.png
# Completed 270.3 KiB/2.7 MiB (40.4 KiB/s) with 900 file(s) remaining
# Completed 273.2 KiB/2.7 MiB (39.8 KiB/s) with 900 file(s) remaining
# upload: dataset\train\bicycle_s_002153.png to s3://project02-khangtictoc/train/bicycle_s_002153.png
# Completed 273.2 KiB/2.7 MiB (39.8 KiB/s) with 899 file(s) remaining
# Completed 275.7 KiB/2.7 MiB (38.9 KiB/s) with 899 file(s) remaining
# upload: dataset\train\bicycle_s_002218.png to s3://project02-khangtictoc/train/bicycle_s_002218.png
# Completed 275.7 KiB/2.7 MiB (38.9 KiB/s) with 898 file(s) remaining
# Completed 277.9 KiB/2.7 MiB (39.1 KiB/s) with 898 file(s) remaining
# upload: dataset\train\bicycle_s_002222.png to s3://project02-khangtictoc/train/bicycle_s_002222.png
# Completed 277.9 KiB/2.7 MiB (39.1 KiB/s) with 897 file(s) remaining
# Completed 280.6 KiB/2.7 MiB (39.5 KiB/s) with 897 file(s) remaining
# upload: dataset\train\bicycle_s_002237.png to s3://project02-khangtictoc/train/bicycle_s_002237.png
# Completed 280.6 KiB/2.7 MiB (39.5 KiB/s) with 896 file(s) remaining
# Completed 283.5 KiB/2.7 MiB (39.8 KiB/s) with 896 file(s) remaining
# upload: dataset\train\bicycle_s_002258.png to s3://project02-khangtictoc/train/bicycle_s_002258.png
# Completed 283.5 KiB/2.7 MiB (39.8 KiB/s) with 895 file(s) remaining
# Completed 285.7 KiB/2.7 MiB (40.0 KiB/s) with 895 file(s) remaining
# upload: dataset\train\bicycle_s_002247.png to s3://project02-khangtictoc/train/bicycle_s_002247.png
# Completed 285.7 KiB/2.7 MiB (40.0 KiB/s) with 894 file(s) remaining
# Completed 288.8 KiB/2.7 MiB (40.4 KiB/s) with 894 file(s) remaining
# upload: dataset\train\bicycle_s_002299.png to s3://project02-khangtictoc/train/bicycle_s_002299.png
# Completed 288.8 KiB/2.7 MiB (40.4 KiB/s) with 893 file(s) remaining
# Completed 291.5 KiB/2.7 MiB (40.6 KiB/s) with 893 file(s) remaining
# upload: dataset\train\bicycle_s_002373.png to s3://project02-khangtictoc/train/bicycle_s_002373.png
# Completed 291.5 KiB/2.7 MiB (40.6 KiB/s) with 892 file(s) remaining
# Completed 294.1 KiB/2.7 MiB (40.9 KiB/s) with 892 file(s) remaining
# upload: dataset\train\bicycle_s_002338.png to s3://project02-khangtictoc/train/bicycle_s_002338.png
# Completed 294.1 KiB/2.7 MiB (40.9 KiB/s) with 891 file(s) remaining
# Completed 297.1 KiB/2.7 MiB (41.0 KiB/s) with 891 file(s) remaining
# upload: dataset\train\bicycle_s_002374.png to s3://project02-khangtictoc/train/bicycle_s_002374.png
# Completed 297.1 KiB/2.7 MiB (41.0 KiB/s) with 890 file(s) remaining
# Completed 299.6 KiB/2.7 MiB (40.5 KiB/s) with 890 file(s) remaining
# upload: dataset\train\bicycle_s_002400.png to s3://project02-khangtictoc/train/bicycle_s_002400.png
# Completed 299.6 KiB/2.7 MiB (40.5 KiB/s) with 889 file(s) remaining
# Completed 302.6 KiB/2.7 MiB (39.7 KiB/s) with 889 file(s) remaining
# upload: dataset\train\bicycle_s_002410.png to s3://project02-khangtictoc/train/bicycle_s_002410.png
# Completed 302.6 KiB/2.7 MiB (39.7 KiB/s) with 888 file(s) remaining
# Completed 305.0 KiB/2.7 MiB (40.0 KiB/s) with 888 file(s) remaining
# upload: dataset\train\bicycle_s_002436.png to s3://project02-khangtictoc/train/bicycle_s_002436.png
# Completed 305.0 KiB/2.7 MiB (40.0 KiB/s) with 887 file(s) remaining
# Completed 307.5 KiB/2.7 MiB (40.2 KiB/s) with 887 file(s) remaining
# upload: dataset\train\bicycle_s_002448.png to s3://project02-khangtictoc/train/bicycle_s_002448.png
# Completed 307.5 KiB/2.7 MiB (40.2 KiB/s) with 886 file(s) remaining
# Completed 310.0 KiB/2.7 MiB (40.4 KiB/s) with 886 file(s) remaining
# upload: dataset\train\bicycle_s_002475.png to s3://project02-khangtictoc/train/bicycle_s_002475.png
# Completed 310.0 KiB/2.7 MiB (40.4 KiB/s) with 885 file(s) remaining
# Completed 312.5 KiB/2.7 MiB (40.7 KiB/s) with 885 file(s) remaining
# upload: dataset\train\bicycle_s_002550.png to s3://project02-khangtictoc/train/bicycle_s_002550.png
# Completed 312.5 KiB/2.7 MiB (40.7 KiB/s) with 884 file(s) remaining
# Completed 315.2 KiB/2.7 MiB (41.1 KiB/s) with 884 file(s) remaining
# upload: dataset\train\bicycle_s_002521.png to s3://project02-khangtictoc/train/bicycle_s_002521.png
# Completed 315.2 KiB/2.7 MiB (41.1 KiB/s) with 883 file(s) remaining
# Completed 317.8 KiB/2.7 MiB (41.1 KiB/s) with 883 file(s) remaining
# upload: dataset\train\bicycle_s_002624.png to s3://project02-khangtictoc/train/bicycle_s_002624.png
# Completed 317.8 KiB/2.7 MiB (41.1 KiB/s) with 882 file(s) remaining
# Completed 320.7 KiB/2.7 MiB (41.4 KiB/s) with 882 file(s) remaining
# upload: dataset\train\bicycle_s_002569.png to s3://project02-khangtictoc/train/bicycle_s_002569.png
# Completed 320.7 KiB/2.7 MiB (41.4 KiB/s) with 881 file(s) remaining
# Completed 323.7 KiB/2.7 MiB (41.7 KiB/s) with 881 file(s) remaining
# upload: dataset\train\bicycle_s_002661.png to s3://project02-khangtictoc/train/bicycle_s_002661.png
# Completed 323.7 KiB/2.7 MiB (41.7 KiB/s) with 880 file(s) remaining
# Completed 326.6 KiB/2.7 MiB (41.2 KiB/s) with 880 file(s) remaining
# upload: dataset\train\bicycle_s_002669.png to s3://project02-khangtictoc/train/bicycle_s_002669.png
# Completed 326.6 KiB/2.7 MiB (41.2 KiB/s) with 879 file(s) remaining
# Completed 329.3 KiB/2.7 MiB (40.4 KiB/s) with 879 file(s) remaining
# upload: dataset\train\bicycle_s_002715.png to s3://project02-khangtictoc/train/bicycle_s_002715.png
# Completed 329.3 KiB/2.7 MiB (40.4 KiB/s) with 878 file(s) remaining
# Completed 332.0 KiB/2.7 MiB (40.7 KiB/s) with 878 file(s) remaining
# upload: dataset\train\bicycle_s_002711.png to s3://project02-khangtictoc/train/bicycle_s_002711.png
# Completed 332.0 KiB/2.7 MiB (40.7 KiB/s) with 877 file(s) remaining
# Completed 334.2 KiB/2.7 MiB (40.7 KiB/s) with 877 file(s) remaining
# upload: dataset\train\bicycle_s_002728.png to s3://project02-khangtictoc/train/bicycle_s_002728.png
# Completed 334.2 KiB/2.7 MiB (40.7 KiB/s) with 876 file(s) remaining
# Completed 336.3 KiB/2.7 MiB (41.0 KiB/s) with 876 file(s) remaining
# upload: dataset\train\bicycle_s_002725.png to s3://project02-khangtictoc/train/bicycle_s_002725.png
# Completed 336.3 KiB/2.7 MiB (41.0 KiB/s) with 875 file(s) remaining
# Completed 339.0 KiB/2.7 MiB (41.3 KiB/s) with 875 file(s) remaining
# upload: dataset\train\bicycle_s_002759.png to s3://project02-khangtictoc/train/bicycle_s_002759.png
# Completed 339.0 KiB/2.7 MiB (41.3 KiB/s) with 874 file(s) remaining
# Completed 341.7 KiB/2.7 MiB (41.6 KiB/s) with 874 file(s) remaining
# upload: dataset\train\bicycle_s_002729.png to s3://project02-khangtictoc/train/bicycle_s_002729.png
# Completed 341.7 KiB/2.7 MiB (41.6 KiB/s) with 873 file(s) remaining
# Completed 344.1 KiB/2.7 MiB (41.6 KiB/s) with 873 file(s) remaining
# upload: dataset\train\bicycle_s_002762.png to s3://project02-khangtictoc/train/bicycle_s_002762.png
# Completed 344.1 KiB/2.7 MiB (41.6 KiB/s) with 872 file(s) remaining
# Completed 347.3 KiB/2.7 MiB (41.9 KiB/s) with 872 file(s) remaining
# upload: dataset\train\bike_s_000001.png to s3://project02-khangtictoc/train/bike_s_000001.png
# Completed 347.3 KiB/2.7 MiB (41.9 KiB/s) with 871 file(s) remaining
# Completed 350.0 KiB/2.7 MiB (42.1 KiB/s) with 871 file(s) remaining
# upload: dataset\train\bike_s_000003.png to s3://project02-khangtictoc/train/bike_s_000003.png
# Completed 350.0 KiB/2.7 MiB (42.1 KiB/s) with 870 file(s) remaining
# Completed 352.8 KiB/2.7 MiB (41.7 KiB/s) with 870 file(s) remaining
# upload: dataset\train\bike_s_000005.png to s3://project02-khangtictoc/train/bike_s_000005.png
# Completed 352.8 KiB/2.7 MiB (41.7 KiB/s) with 869 file(s) remaining
# Completed 355.8 KiB/2.7 MiB (41.0 KiB/s) with 869 file(s) remaining
# upload: dataset\train\bike_s_000015.png to s3://project02-khangtictoc/train/bike_s_000015.png
# Completed 355.8 KiB/2.7 MiB (41.0 KiB/s) with 868 file(s) remaining
# Completed 358.7 KiB/2.7 MiB (41.3 KiB/s) with 868 file(s) remaining
# upload: dataset\train\bike_s_000018.png to s3://project02-khangtictoc/train/bike_s_000018.png
# Completed 358.7 KiB/2.7 MiB (41.3 KiB/s) with 867 file(s) remaining
# Completed 361.4 KiB/2.7 MiB (41.4 KiB/s) with 867 file(s) remaining
# upload: dataset\train\bike_s_000021.png to s3://project02-khangtictoc/train/bike_s_000021.png
# Completed 361.4 KiB/2.7 MiB (41.4 KiB/s) with 866 file(s) remaining
# Completed 364.2 KiB/2.7 MiB (41.7 KiB/s) with 866 file(s) remaining
# upload: dataset\train\bike_s_000025.png to s3://project02-khangtictoc/train/bike_s_000025.png
# Completed 364.2 KiB/2.7 MiB (41.7 KiB/s) with 865 file(s) remaining
# Completed 367.1 KiB/2.7 MiB (42.0 KiB/s) with 865 file(s) remaining
# upload: dataset\train\bike_s_000024.png to s3://project02-khangtictoc/train/bike_s_000024.png
# Completed 367.1 KiB/2.7 MiB (42.0 KiB/s) with 864 file(s) remaining
# Completed 370.2 KiB/2.7 MiB (42.3 KiB/s) with 864 file(s) remaining
# upload: dataset\train\bike_s_000023.png to s3://project02-khangtictoc/train/bike_s_000023.png
# Completed 370.2 KiB/2.7 MiB (42.3 KiB/s) with 863 file(s) remaining
# Completed 373.0 KiB/2.7 MiB (42.2 KiB/s) with 863 file(s) remaining
# upload: dataset\train\bike_s_000026.png to s3://project02-khangtictoc/train/bike_s_000026.png
# Completed 373.0 KiB/2.7 MiB (42.2 KiB/s) with 862 file(s) remaining
# Completed 375.7 KiB/2.7 MiB (42.5 KiB/s) with 862 file(s) remaining
# upload: dataset\train\bike_s_000034.png to s3://project02-khangtictoc/train/bike_s_000034.png
# Completed 375.7 KiB/2.7 MiB (42.5 KiB/s) with 861 file(s) remaining
# Completed 378.8 KiB/2.7 MiB (42.8 KiB/s) with 861 file(s) remaining
# upload: dataset\train\bike_s_000035.png to s3://project02-khangtictoc/train/bike_s_000035.png
# Completed 378.8 KiB/2.7 MiB (42.8 KiB/s) with 860 file(s) remaining
# Completed 381.5 KiB/2.7 MiB (42.4 KiB/s) with 860 file(s) remaining
# upload: dataset\train\bike_s_000040.png to s3://project02-khangtictoc/train/bike_s_000040.png
# Completed 381.5 KiB/2.7 MiB (42.4 KiB/s) with 859 file(s) remaining
# Completed 384.3 KiB/2.7 MiB (41.8 KiB/s) with 859 file(s) remaining
# upload: dataset\train\bike_s_000051.png to s3://project02-khangtictoc/train/bike_s_000051.png
# Completed 384.3 KiB/2.7 MiB (41.8 KiB/s) with 858 file(s) remaining
# Completed 386.9 KiB/2.7 MiB (42.0 KiB/s) with 858 file(s) remaining
# upload: dataset\train\bike_s_000062.png to s3://project02-khangtictoc/train/bike_s_000062.png
# Completed 386.9 KiB/2.7 MiB (42.0 KiB/s) with 857 file(s) remaining
# Completed 389.5 KiB/2.7 MiB (42.0 KiB/s) with 857 file(s) remaining
# upload: dataset\train\bike_s_000111.png to s3://project02-khangtictoc/train/bike_s_000111.png
# Completed 389.5 KiB/2.7 MiB (42.0 KiB/s) with 856 file(s) remaining
# Completed 392.5 KiB/2.7 MiB (42.3 KiB/s) with 856 file(s) remaining
# upload: dataset\train\bike_s_000129.png to s3://project02-khangtictoc/train/bike_s_000129.png
# Completed 392.5 KiB/2.7 MiB (42.3 KiB/s) with 855 file(s) remaining
# Completed 395.3 KiB/2.7 MiB (42.6 KiB/s) with 855 file(s) remaining
# upload: dataset\train\bike_s_000127.png to s3://project02-khangtictoc/train/bike_s_000127.png
# Completed 395.3 KiB/2.7 MiB (42.6 KiB/s) with 854 file(s) remaining
# Completed 397.8 KiB/2.7 MiB (42.8 KiB/s) with 854 file(s) remaining
# upload: dataset\train\bike_s_000121.png to s3://project02-khangtictoc/train/bike_s_000121.png
# Completed 397.8 KiB/2.7 MiB (42.8 KiB/s) with 853 file(s) remaining
# Completed 400.7 KiB/2.7 MiB (42.7 KiB/s) with 853 file(s) remaining
# upload: dataset\train\bike_s_000162.png to s3://project02-khangtictoc/train/bike_s_000162.png
# Completed 400.7 KiB/2.7 MiB (42.7 KiB/s) with 852 file(s) remaining
# Completed 403.3 KiB/2.7 MiB (43.0 KiB/s) with 852 file(s) remaining
# upload: dataset\train\bike_s_000164.png to s3://project02-khangtictoc/train/bike_s_000164.png
# Completed 403.3 KiB/2.7 MiB (43.0 KiB/s) with 851 file(s) remaining
# Completed 406.2 KiB/2.7 MiB (43.2 KiB/s) with 851 file(s) remaining
# upload: dataset\train\bike_s_000154.png to s3://project02-khangtictoc/train/bike_s_000154.png
# Completed 406.2 KiB/2.7 MiB (43.2 KiB/s) with 850 file(s) remaining
# Completed 408.7 KiB/2.7 MiB (42.9 KiB/s) with 850 file(s) remaining
# upload: dataset\train\bike_s_000204.png to s3://project02-khangtictoc/train/bike_s_000204.png
# Completed 408.7 KiB/2.7 MiB (42.9 KiB/s) with 849 file(s) remaining
# Completed 411.8 KiB/2.7 MiB (42.3 KiB/s) with 849 file(s) remaining
# upload: dataset\train\bike_s_000237.png to s3://project02-khangtictoc/train/bike_s_000237.png
# Completed 411.8 KiB/2.7 MiB (42.3 KiB/s) with 848 file(s) remaining
# Completed 414.7 KiB/2.7 MiB (42.6 KiB/s) with 848 file(s) remaining
# upload: dataset\train\bike_s_000256.png to s3://project02-khangtictoc/train/bike_s_000256.png
# Completed 414.7 KiB/2.7 MiB (42.6 KiB/s) with 847 file(s) remaining
# Completed 417.5 KiB/2.7 MiB (42.5 KiB/s) with 847 file(s) remaining
# upload: dataset\train\bike_s_000299.png to s3://project02-khangtictoc/train/bike_s_000299.png
# Completed 417.5 KiB/2.7 MiB (42.5 KiB/s) with 846 file(s) remaining
# Completed 420.2 KiB/2.7 MiB (42.8 KiB/s) with 846 file(s) remaining
# upload: dataset\train\bike_s_000304.png to s3://project02-khangtictoc/train/bike_s_000304.png
# Completed 420.2 KiB/2.7 MiB (42.8 KiB/s) with 845 file(s) remaining
# Completed 423.0 KiB/2.7 MiB (43.1 KiB/s) with 845 file(s) remaining
# upload: dataset\train\bike_s_000336.png to s3://project02-khangtictoc/train/bike_s_000336.png
# Completed 423.0 KiB/2.7 MiB (43.1 KiB/s) with 844 file(s) remaining
# Completed 425.5 KiB/2.7 MiB (43.3 KiB/s) with 844 file(s) remaining
# upload: dataset\train\bike_s_000302.png to s3://project02-khangtictoc/train/bike_s_000302.png
# Completed 425.5 KiB/2.7 MiB (43.3 KiB/s) with 843 file(s) remaining
# Completed 428.0 KiB/2.7 MiB (43.0 KiB/s) with 843 file(s) remaining
# upload: dataset\train\bike_s_000390.png to s3://project02-khangtictoc/train/bike_s_000390.png
# Completed 428.0 KiB/2.7 MiB (43.0 KiB/s) with 842 file(s) remaining
# Completed 430.7 KiB/2.7 MiB (43.3 KiB/s) with 842 file(s) remaining
# upload: dataset\train\bike_s_000392.png to s3://project02-khangtictoc/train/bike_s_000392.png
# Completed 430.7 KiB/2.7 MiB (43.3 KiB/s) with 841 file(s) remaining
# Completed 433.6 KiB/2.7 MiB (43.4 KiB/s) with 841 file(s) remaining
# upload: dataset\train\bike_s_000364.png to s3://project02-khangtictoc/train/bike_s_000364.png
# Completed 433.6 KiB/2.7 MiB (43.4 KiB/s) with 840 file(s) remaining
# Completed 436.5 KiB/2.7 MiB (43.4 KiB/s) with 840 file(s) remaining
# upload: dataset\train\bike_s_000397.png to s3://project02-khangtictoc/train/bike_s_000397.png
# Completed 436.5 KiB/2.7 MiB (43.4 KiB/s) with 839 file(s) remaining
# Completed 439.2 KiB/2.7 MiB (42.7 KiB/s) with 839 file(s) remaining
# upload: dataset\train\bike_s_000474.png to s3://project02-khangtictoc/train/bike_s_000474.png
# Completed 439.2 KiB/2.7 MiB (42.7 KiB/s) with 838 file(s) remaining
# Completed 442.1 KiB/2.7 MiB (42.9 KiB/s) with 838 file(s) remaining
# upload: dataset\train\bike_s_000506.png to s3://project02-khangtictoc/train/bike_s_000506.png
# Completed 442.1 KiB/2.7 MiB (42.9 KiB/s) with 837 file(s) remaining
# Completed 445.1 KiB/2.7 MiB (43.0 KiB/s) with 837 file(s) remaining
# upload: dataset\train\bike_s_000516.png to s3://project02-khangtictoc/train/bike_s_000516.png
# Completed 445.1 KiB/2.7 MiB (43.0 KiB/s) with 836 file(s) remaining
# Completed 448.0 KiB/2.7 MiB (43.2 KiB/s) with 836 file(s) remaining
# upload: dataset\train\bike_s_000522.png to s3://project02-khangtictoc/train/bike_s_000522.png
# Completed 448.0 KiB/2.7 MiB (43.2 KiB/s) with 835 file(s) remaining
# Completed 450.8 KiB/2.7 MiB (43.5 KiB/s) with 835 file(s) remaining
# upload: dataset\train\bike_s_000544.png to s3://project02-khangtictoc/train/bike_s_000544.png
# Completed 450.8 KiB/2.7 MiB (43.5 KiB/s) with 834 file(s) remaining
# Completed 453.7 KiB/2.7 MiB (43.8 KiB/s) with 834 file(s) remaining
# upload: dataset\train\bike_s_000545.png to s3://project02-khangtictoc/train/bike_s_000545.png
# Completed 453.7 KiB/2.7 MiB (43.8 KiB/s) with 833 file(s) remaining
# Completed 456.2 KiB/2.7 MiB (43.4 KiB/s) with 833 file(s) remaining
# upload: dataset\train\bike_s_000593.png to s3://project02-khangtictoc/train/bike_s_000593.png
# Completed 456.2 KiB/2.7 MiB (43.4 KiB/s) with 832 file(s) remaining
# Completed 459.0 KiB/2.7 MiB (43.7 KiB/s) with 832 file(s) remaining
# upload: dataset\train\bike_s_000555.png to s3://project02-khangtictoc/train/bike_s_000555.png
# Completed 459.0 KiB/2.7 MiB (43.7 KiB/s) with 831 file(s) remaining
# Completed 461.9 KiB/2.7 MiB (43.9 KiB/s) with 831 file(s) remaining
# upload: dataset\train\bike_s_000628.png to s3://project02-khangtictoc/train/bike_s_000628.png
# Completed 461.9 KiB/2.7 MiB (43.9 KiB/s) with 830 file(s) remaining
# Completed 464.7 KiB/2.7 MiB (43.9 KiB/s) with 830 file(s) remaining
# upload: dataset\train\bike_s_000657.png to s3://project02-khangtictoc/train/bike_s_000657.png
# Completed 464.7 KiB/2.7 MiB (43.9 KiB/s) with 829 file(s) remaining
# Completed 467.6 KiB/2.7 MiB (43.2 KiB/s) with 829 file(s) remaining
# upload: dataset\train\bike_s_000679.png to s3://project02-khangtictoc/train/bike_s_000679.png
# Completed 467.6 KiB/2.7 MiB (43.2 KiB/s) with 828 file(s) remaining
# Completed 470.6 KiB/2.7 MiB (43.5 KiB/s) with 828 file(s) remaining
# upload: dataset\train\bike_s_000682.png to s3://project02-khangtictoc/train/bike_s_000682.png
# Completed 470.6 KiB/2.7 MiB (43.5 KiB/s) with 827 file(s) remaining
# Completed 473.2 KiB/2.7 MiB (43.5 KiB/s) with 827 file(s) remaining
# upload: dataset\train\bike_s_000722.png to s3://project02-khangtictoc/train/bike_s_000722.png
# Completed 473.2 KiB/2.7 MiB (43.5 KiB/s) with 826 file(s) remaining
# Completed 476.2 KiB/2.7 MiB (43.7 KiB/s) with 826 file(s) remaining
# upload: dataset\train\bike_s_000855.png to s3://project02-khangtictoc/train/bike_s_000855.png
# Completed 476.2 KiB/2.7 MiB (43.7 KiB/s) with 825 file(s) remaining
# Completed 478.6 KiB/2.7 MiB (43.9 KiB/s) with 825 file(s) remaining
# upload: dataset\train\bike_s_000926.png to s3://project02-khangtictoc/train/bike_s_000926.png
# Completed 478.6 KiB/2.7 MiB (43.9 KiB/s) with 824 file(s) remaining
# Completed 481.4 KiB/2.7 MiB (43.9 KiB/s) with 824 file(s) remaining
# upload: dataset\train\bike_s_000934.png to s3://project02-khangtictoc/train/bike_s_000934.png
# Completed 481.4 KiB/2.7 MiB (43.9 KiB/s) with 823 file(s) remaining
# Completed 483.7 KiB/2.7 MiB (43.8 KiB/s) with 823 file(s) remaining
# upload: dataset\train\bike_s_000990.png to s3://project02-khangtictoc/train/bike_s_000990.png
# Completed 483.7 KiB/2.7 MiB (43.8 KiB/s) with 822 file(s) remaining
# Completed 486.7 KiB/2.7 MiB (44.0 KiB/s) with 822 file(s) remaining
# upload: dataset\train\bike_s_001027.png to s3://project02-khangtictoc/train/bike_s_001027.png
# Completed 486.7 KiB/2.7 MiB (44.0 KiB/s) with 821 file(s) remaining
# Completed 489.3 KiB/2.7 MiB (44.1 KiB/s) with 821 file(s) remaining
# upload: dataset\train\bike_s_001072.png to s3://project02-khangtictoc/train/bike_s_001072.png
# Completed 489.3 KiB/2.7 MiB (44.1 KiB/s) with 820 file(s) remaining
# Completed 492.1 KiB/2.7 MiB (44.3 KiB/s) with 820 file(s) remaining
# upload: dataset\train\bike_s_001078.png to s3://project02-khangtictoc/train/bike_s_001078.png
# Completed 492.1 KiB/2.7 MiB (44.3 KiB/s) with 819 file(s) remaining
# Completed 494.8 KiB/2.7 MiB (43.6 KiB/s) with 819 file(s) remaining
# upload: dataset\train\bike_s_001113.png to s3://project02-khangtictoc/train/bike_s_001113.png
# Completed 494.8 KiB/2.7 MiB (43.6 KiB/s) with 818 file(s) remaining
# Completed 497.7 KiB/2.7 MiB (43.9 KiB/s) with 818 file(s) remaining
# upload: dataset\train\bike_s_001093.png to s3://project02-khangtictoc/train/bike_s_001093.png
# Completed 497.7 KiB/2.7 MiB (43.9 KiB/s) with 817 file(s) remaining
# Completed 500.6 KiB/2.7 MiB (43.9 KiB/s) with 817 file(s) remaining
# upload: dataset\train\bike_s_001116.png to s3://project02-khangtictoc/train/bike_s_001116.png
# Completed 500.6 KiB/2.7 MiB (43.9 KiB/s) with 816 file(s) remaining
# Completed 503.2 KiB/2.7 MiB (44.0 KiB/s) with 816 file(s) remaining
# upload: dataset\train\bike_s_001131.png to s3://project02-khangtictoc/train/bike_s_001131.png
# Completed 503.2 KiB/2.7 MiB (44.0 KiB/s) with 815 file(s) remaining
# Completed 506.0 KiB/2.7 MiB (44.2 KiB/s) with 815 file(s) remaining
# upload: dataset\train\bike_s_001200.png to s3://project02-khangtictoc/train/bike_s_001200.png
# Completed 506.0 KiB/2.7 MiB (44.2 KiB/s) with 814 file(s) remaining
# Completed 508.8 KiB/2.7 MiB (43.9 KiB/s) with 814 file(s) remaining
# upload: dataset\train\bike_s_001226.png to s3://project02-khangtictoc/train/bike_s_001226.png
# Completed 508.8 KiB/2.7 MiB (43.9 KiB/s) with 813 file(s) remaining
# Completed 511.8 KiB/2.7 MiB (44.1 KiB/s) with 813 file(s) remaining
# upload: dataset\train\bike_s_001260.png to s3://project02-khangtictoc/train/bike_s_001260.png
# Completed 511.8 KiB/2.7 MiB (44.1 KiB/s) with 812 file(s) remaining
# Completed 514.4 KiB/2.7 MiB (44.3 KiB/s) with 812 file(s) remaining
# upload: dataset\train\bike_s_001320.png to s3://project02-khangtictoc/train/bike_s_001320.png
# Completed 514.4 KiB/2.7 MiB (44.3 KiB/s) with 811 file(s) remaining
# Completed 517.2 KiB/2.7 MiB (44.4 KiB/s) with 811 file(s) remaining
# upload: dataset\train\bike_s_001380.png to s3://project02-khangtictoc/train/bike_s_001380.png
# Completed 517.2 KiB/2.7 MiB (44.4 KiB/s) with 810 file(s) remaining
# Completed 520.0 KiB/2.7 MiB (44.6 KiB/s) with 810 file(s) remaining
# upload: dataset\train\bike_s_001375.png to s3://project02-khangtictoc/train/bike_s_001375.png
# Completed 520.0 KiB/2.7 MiB (44.6 KiB/s) with 809 file(s) remaining
# Completed 522.5 KiB/2.7 MiB (44.0 KiB/s) with 809 file(s) remaining
# upload: dataset\train\bike_s_001414.png to s3://project02-khangtictoc/train/bike_s_001414.png
# Completed 522.5 KiB/2.7 MiB (44.0 KiB/s) with 808 file(s) remaining
# Completed 525.4 KiB/2.7 MiB (44.2 KiB/s) with 808 file(s) remaining
# upload: dataset\train\bike_s_001415.png to s3://project02-khangtictoc/train/bike_s_001415.png
# Completed 525.4 KiB/2.7 MiB (44.2 KiB/s) with 807 file(s) remaining
# Completed 527.9 KiB/2.7 MiB (44.2 KiB/s) with 807 file(s) remaining
# upload: dataset\train\bike_s_001418.png to s3://project02-khangtictoc/train/bike_s_001418.png
# Completed 527.9 KiB/2.7 MiB (44.2 KiB/s) with 806 file(s) remaining
# Completed 530.3 KiB/2.7 MiB (44.3 KiB/s) with 806 file(s) remaining
# upload: dataset\train\bike_s_001517.png to s3://project02-khangtictoc/train/bike_s_001517.png
# Completed 530.3 KiB/2.7 MiB (44.3 KiB/s) with 805 file(s) remaining
# Completed 532.8 KiB/2.7 MiB (44.5 KiB/s) with 805 file(s) remaining
# upload: dataset\train\bike_s_001462.png to s3://project02-khangtictoc/train/bike_s_001462.png
# Completed 532.8 KiB/2.7 MiB (44.5 KiB/s) with 804 file(s) remaining
# Completed 535.7 KiB/2.7 MiB (44.1 KiB/s) with 804 file(s) remaining
# upload: dataset\train\bike_s_001519.png to s3://project02-khangtictoc/train/bike_s_001519.png
# Completed 535.7 KiB/2.7 MiB (44.1 KiB/s) with 803 file(s) remaining
# Completed 538.4 KiB/2.7 MiB (44.2 KiB/s) with 803 file(s) remaining
# upload: dataset\train\bike_s_001572.png to s3://project02-khangtictoc/train/bike_s_001572.png
# Completed 538.4 KiB/2.7 MiB (44.2 KiB/s) with 802 file(s) remaining
# Completed 541.0 KiB/2.7 MiB (44.4 KiB/s) with 802 file(s) remaining
# upload: dataset\train\bike_s_001592.png to s3://project02-khangtictoc/train/bike_s_001592.png
# Completed 541.0 KiB/2.7 MiB (44.4 KiB/s) with 801 file(s) remaining
# Completed 544.0 KiB/2.7 MiB (44.7 KiB/s) with 801 file(s) remaining
# upload: dataset\train\bike_s_001613.png to s3://project02-khangtictoc/train/bike_s_001613.png
# Completed 544.0 KiB/2.7 MiB (44.7 KiB/s) with 800 file(s) remaining
# Completed 547.0 KiB/2.7 MiB (44.8 KiB/s) with 800 file(s) remaining
# upload: dataset\train\bike_s_001679.png to s3://project02-khangtictoc/train/bike_s_001679.png
# Completed 547.0 KiB/2.7 MiB (44.8 KiB/s) with 799 file(s) remaining
# Completed 549.8 KiB/2.7 MiB (44.3 KiB/s) with 799 file(s) remaining
# upload: dataset\train\bike_s_001683.png to s3://project02-khangtictoc/train/bike_s_001683.png
# Completed 549.8 KiB/2.7 MiB (44.3 KiB/s) with 798 file(s) remaining
# Completed 552.4 KiB/2.7 MiB (44.5 KiB/s) with 798 file(s) remaining
# upload: dataset\train\bike_s_001739.png to s3://project02-khangtictoc/train/bike_s_001739.png
# Completed 552.4 KiB/2.7 MiB (44.5 KiB/s) with 797 file(s) remaining
# Completed 555.3 KiB/2.7 MiB (44.4 KiB/s) with 797 file(s) remaining
# upload: dataset\train\bike_s_001761.png to s3://project02-khangtictoc/train/bike_s_001761.png
# Completed 555.3 KiB/2.7 MiB (44.4 KiB/s) with 796 file(s) remaining
# Completed 558.2 KiB/2.7 MiB (44.6 KiB/s) with 796 file(s) remaining
# upload: dataset\train\bike_s_001767.png to s3://project02-khangtictoc/train/bike_s_001767.png
# Completed 558.2 KiB/2.7 MiB (44.6 KiB/s) with 795 file(s) remaining
# Completed 560.9 KiB/2.7 MiB (44.8 KiB/s) with 795 file(s) remaining
# upload: dataset\train\bike_s_001827.png to s3://project02-khangtictoc/train/bike_s_001827.png
# ...
# upload: dataset\test\motorcycle_s_001269.png to s3://project02-khangtictoc/test/motorcycle_s_001269.png
# Completed 370.7 KiB/544.6 KiB (45.7 KiB/s) with 65 file(s) remaining
# Completed 373.7 KiB/544.6 KiB (45.8 KiB/s) with 65 file(s) remaining
# upload: dataset\test\motorcycle_s_001348.png to s3://project02-khangtictoc/test/motorcycle_s_001348.png
# Completed 373.7 KiB/544.6 KiB (45.8 KiB/s) with 64 file(s) remaining
# Completed 376.4 KiB/544.6 KiB (46.1 KiB/s) with 64 file(s) remaining
# upload: dataset\test\motorcycle_s_001385.png to s3://project02-khangtictoc/test/motorcycle_s_001385.png
# Completed 376.4 KiB/544.6 KiB (46.1 KiB/s) with 63 file(s) remaining
# Completed 379.0 KiB/544.6 KiB (46.3 KiB/s) with 63 file(s) remaining
# upload: dataset\test\motorcycle_s_001508.png to s3://project02-khangtictoc/test/motorcycle_s_001508.png
# Completed 379.0 KiB/544.6 KiB (46.3 KiB/s) with 62 file(s) remaining
# Completed 382.0 KiB/544.6 KiB (46.3 KiB/s) with 62 file(s) remaining
# upload: dataset\test\motorcycle_s_001519.png to s3://project02-khangtictoc/test/motorcycle_s_001519.png
# Completed 382.0 KiB/544.6 KiB (46.3 KiB/s) with 61 file(s) remaining
# Completed 385.1 KiB/544.6 KiB (46.4 KiB/s) with 61 file(s) remaining
# upload: dataset\test\motorcycle_s_001679.png to s3://project02-khangtictoc/test/motorcycle_s_001679.png
# Completed 385.1 KiB/544.6 KiB (46.4 KiB/s) with 60 file(s) remaining
# Completed 387.1 KiB/544.6 KiB (45.9 KiB/s) with 60 file(s) remaining
# upload: dataset\test\motorcycle_s_001687.png to s3://project02-khangtictoc/test/motorcycle_s_001687.png
# Completed 387.1 KiB/544.6 KiB (45.9 KiB/s) with 59 file(s) remaining
# Completed 390.3 KiB/544.6 KiB (45.9 KiB/s) with 59 file(s) remaining
# upload: dataset\test\motorcycle_s_001782.png to s3://project02-khangtictoc/test/motorcycle_s_001782.png
# Completed 390.3 KiB/544.6 KiB (45.9 KiB/s) with 58 file(s) remaining
# Completed 393.0 KiB/544.6 KiB (45.9 KiB/s) with 58 file(s) remaining
# Completed 396.0 KiB/544.6 KiB (46.3 KiB/s) with 58 file(s) remaining
# upload: dataset\test\motorcycle_s_001892.png to s3://project02-khangtictoc/test/motorcycle_s_001892.png
# Completed 396.0 KiB/544.6 KiB (46.3 KiB/s) with 57 file(s) remaining
# upload: dataset\test\motorcycle_s_001906.png to s3://project02-khangtictoc/test/motorcycle_s_001906.png
# Completed 396.0 KiB/544.6 KiB (46.3 KiB/s) with 56 file(s) remaining
# Completed 399.0 KiB/544.6 KiB (46.2 KiB/s) with 56 file(s) remaining
# upload: dataset\test\motorcycle_s_001936.png to s3://project02-khangtictoc/test/motorcycle_s_001936.png
# Completed 399.0 KiB/544.6 KiB (46.2 KiB/s) with 55 file(s) remaining
# Completed 401.9 KiB/544.6 KiB (46.1 KiB/s) with 55 file(s) remaining
# Completed 403.8 KiB/544.6 KiB (46.3 KiB/s) with 55 file(s) remaining
# upload: dataset\test\motorcycle_s_001960.png to s3://project02-khangtictoc/test/motorcycle_s_001960.png
# Completed 403.8 KiB/544.6 KiB (46.3 KiB/s) with 54 file(s) remaining
# upload: dataset\test\motorcycle_s_001955.png to s3://project02-khangtictoc/test/motorcycle_s_001955.png
# Completed 403.8 KiB/544.6 KiB (46.3 KiB/s) with 53 file(s) remaining
# Completed 406.0 KiB/544.6 KiB (46.5 KiB/s) with 53 file(s) remaining
# upload: dataset\test\motorcycle_s_001971.png to s3://project02-khangtictoc/test/motorcycle_s_001971.png
# Completed 406.0 KiB/544.6 KiB (46.5 KiB/s) with 52 file(s) remaining
# Completed 408.5 KiB/544.6 KiB (46.5 KiB/s) with 52 file(s) remaining
# upload: dataset\test\motorcycle_s_002026.png to s3://project02-khangtictoc/test/motorcycle_s_002026.png
# Completed 408.5 KiB/544.6 KiB (46.5 KiB/s) with 51 file(s) remaining
# Completed 410.6 KiB/544.6 KiB (46.4 KiB/s) with 51 file(s) remaining
# upload: dataset\test\motorcycle_s_002112.png to s3://project02-khangtictoc/test/motorcycle_s_002112.png
# Completed 410.6 KiB/544.6 KiB (46.4 KiB/s) with 50 file(s) remaining
# Completed 412.8 KiB/544.6 KiB (45.8 KiB/s) with 50 file(s) remaining
# upload: dataset\test\motorcycle_s_002126.png to s3://project02-khangtictoc/test/motorcycle_s_002126.png
# Completed 412.8 KiB/544.6 KiB (45.8 KiB/s) with 49 file(s) remaining
# Completed 415.8 KiB/544.6 KiB (46.0 KiB/s) with 49 file(s) remaining
# upload: dataset\test\motorcycle_s_002177.png to s3://project02-khangtictoc/test/motorcycle_s_002177.png
# Completed 415.8 KiB/544.6 KiB (46.0 KiB/s) with 48 file(s) remaining
# Completed 418.3 KiB/544.6 KiB (46.0 KiB/s) with 48 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000105.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000105.png
# Completed 418.3 KiB/544.6 KiB (46.0 KiB/s) with 47 file(s) remaining
# Completed 421.0 KiB/544.6 KiB (46.0 KiB/s) with 47 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000158.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000158.png
# Completed 421.0 KiB/544.6 KiB (46.0 KiB/s) with 46 file(s) remaining
# Completed 423.3 KiB/544.6 KiB (46.2 KiB/s) with 46 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000113.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000113.png
# Completed 423.3 KiB/544.6 KiB (46.2 KiB/s) with 45 file(s) remaining
# Completed 425.9 KiB/544.6 KiB (46.1 KiB/s) with 45 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000284.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000284.png
# Completed 425.9 KiB/544.6 KiB (46.1 KiB/s) with 44 file(s) remaining
# Completed 428.4 KiB/544.6 KiB (46.3 KiB/s) with 44 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000169.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000169.png
# Completed 428.4 KiB/544.6 KiB (46.3 KiB/s) with 43 file(s) remaining
# Completed 431.2 KiB/544.6 KiB (46.4 KiB/s) with 43 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000350.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000350.png
# Completed 431.2 KiB/544.6 KiB (46.4 KiB/s) with 42 file(s) remaining
# Completed 433.5 KiB/544.6 KiB (46.4 KiB/s) with 42 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000431.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000431.png
# Completed 433.5 KiB/544.6 KiB (46.4 KiB/s) with 41 file(s) remaining
# Completed 435.9 KiB/544.6 KiB (46.3 KiB/s) with 41 file(s) remaining
# upload: dataset\test\ordinary_bicycle_s_000437.png to s3://project02-khangtictoc/test/ordinary_bicycle_s_000437.png
# Completed 435.9 KiB/544.6 KiB (46.3 KiB/s) with 40 file(s) remaining
# Completed 438.5 KiB/544.6 KiB (45.8 KiB/s) with 40 file(s) remaining
# upload: dataset\test\safety_bicycle_s_000235.png to s3://project02-khangtictoc/test/safety_bicycle_s_000235.png
# Completed 438.5 KiB/544.6 KiB (45.8 KiB/s) with 39 file(s) remaining
# Completed 440.8 KiB/544.6 KiB (46.0 KiB/s) with 39 file(s) remaining
# upload: dataset\test\safety_bicycle_s_000280.png to s3://project02-khangtictoc/test/safety_bicycle_s_000280.png
# Completed 440.8 KiB/544.6 KiB (46.0 KiB/s) with 38 file(s) remaining
# Completed 443.3 KiB/544.6 KiB (46.0 KiB/s) with 38 file(s) remaining
# upload: dataset\test\safety_bicycle_s_000315.png to s3://project02-khangtictoc/test/safety_bicycle_s_000315.png
# Completed 443.3 KiB/544.6 KiB (46.0 KiB/s) with 37 file(s) remaining
# Completed 445.7 KiB/544.6 KiB (46.0 KiB/s) with 37 file(s) remaining
# upload: dataset\test\safety_bicycle_s_001153.png to s3://project02-khangtictoc/test/safety_bicycle_s_001153.png
# Completed 445.7 KiB/544.6 KiB (46.0 KiB/s) with 36 file(s) remaining
# Completed 448.2 KiB/544.6 KiB (46.2 KiB/s) with 36 file(s) remaining
# upload: dataset\test\safety_bicycle_s_001286.png to s3://project02-khangtictoc/test/safety_bicycle_s_001286.png
# Completed 448.2 KiB/544.6 KiB (46.2 KiB/s) with 35 file(s) remaining
# Completed 451.2 KiB/544.6 KiB (46.0 KiB/s) with 35 file(s) remaining
# upload: dataset\test\safety_bicycle_s_001575.png to s3://project02-khangtictoc/test/safety_bicycle_s_001575.png
# Completed 451.2 KiB/544.6 KiB (46.0 KiB/s) with 34 file(s) remaining
# Completed 454.1 KiB/544.6 KiB (46.3 KiB/s) with 34 file(s) remaining
# upload: dataset\test\safety_bicycle_s_001322.png to s3://project02-khangtictoc/test/safety_bicycle_s_001322.png
# Completed 454.1 KiB/544.6 KiB (46.3 KiB/s) with 33 file(s) remaining
# Completed 456.8 KiB/544.6 KiB (46.4 KiB/s) with 33 file(s) remaining
# upload: dataset\test\safety_bike_s_000192.png to s3://project02-khangtictoc/test/safety_bike_s_000192.png
# Completed 456.8 KiB/544.6 KiB (46.4 KiB/s) with 32 file(s) remaining
# Completed 459.8 KiB/544.6 KiB (46.5 KiB/s) with 32 file(s) remaining
# upload: dataset\test\safety_bike_s_000390.png to s3://project02-khangtictoc/test/safety_bike_s_000390.png
# Completed 459.8 KiB/544.6 KiB (46.5 KiB/s) with 31 file(s) remaining
# Completed 462.7 KiB/544.6 KiB (46.3 KiB/s) with 31 file(s) remaining
# upload: dataset\test\safety_bike_s_000438.png to s3://project02-khangtictoc/test/safety_bike_s_000438.png
# Completed 462.7 KiB/544.6 KiB (46.3 KiB/s) with 30 file(s) remaining
# Completed 465.4 KiB/544.6 KiB (46.1 KiB/s) with 30 file(s) remaining
# upload: dataset\test\safety_bike_s_000540.png to s3://project02-khangtictoc/test/safety_bike_s_000540.png
# Completed 465.4 KiB/544.6 KiB (46.1 KiB/s) with 29 file(s) remaining
# Completed 468.2 KiB/544.6 KiB (46.1 KiB/s) with 29 file(s) remaining
# upload: dataset\test\safety_bike_s_000488.png to s3://project02-khangtictoc/test/safety_bike_s_000488.png
# Completed 468.2 KiB/544.6 KiB (46.1 KiB/s) with 28 file(s) remaining
# Completed 471.1 KiB/544.6 KiB (46.4 KiB/s) with 28 file(s) remaining
# upload: dataset\test\safety_bike_s_000541.png to s3://project02-khangtictoc/test/safety_bike_s_000541.png
# Completed 471.1 KiB/544.6 KiB (46.4 KiB/s) with 27 file(s) remaining
# Completed 474.2 KiB/544.6 KiB (46.3 KiB/s) with 27 file(s) remaining
# upload: dataset\test\safety_bike_s_000791.png to s3://project02-khangtictoc/test/safety_bike_s_000791.png
# Completed 474.2 KiB/544.6 KiB (46.3 KiB/s) with 26 file(s) remaining
# Completed 476.9 KiB/544.6 KiB (46.5 KiB/s) with 26 file(s) remaining
# upload: dataset\test\safety_bike_s_000699.png to s3://project02-khangtictoc/test/safety_bike_s_000699.png
# Completed 476.9 KiB/544.6 KiB (46.5 KiB/s) with 25 file(s) remaining
# Completed 479.7 KiB/544.6 KiB (46.5 KiB/s) with 25 file(s) remaining
# upload: dataset\test\safety_bike_s_001065.png to s3://project02-khangtictoc/test/safety_bike_s_001065.png
# Completed 479.7 KiB/544.6 KiB (46.5 KiB/s) with 24 file(s) remaining
# Completed 482.5 KiB/544.6 KiB (46.7 KiB/s) with 24 file(s) remaining
# upload: dataset\test\safety_bike_s_001087.png to s3://project02-khangtictoc/test/safety_bike_s_001087.png
# Completed 482.5 KiB/544.6 KiB (46.7 KiB/s) with 23 file(s) remaining
# Completed 485.1 KiB/544.6 KiB (46.8 KiB/s) with 23 file(s) remaining
# upload: dataset\test\safety_bike_s_001088.png to s3://project02-khangtictoc/test/safety_bike_s_001088.png
# Completed 485.1 KiB/544.6 KiB (46.8 KiB/s) with 22 file(s) remaining
# Completed 487.8 KiB/544.6 KiB (46.7 KiB/s) with 22 file(s) remaining
# upload: dataset\test\safety_bike_s_001132.png to s3://project02-khangtictoc/test/safety_bike_s_001132.png
# Completed 487.8 KiB/544.6 KiB (46.7 KiB/s) with 21 file(s) remaining
# Completed 490.6 KiB/544.6 KiB (46.6 KiB/s) with 21 file(s) remaining
# upload: dataset\test\safety_bike_s_001253.png to s3://project02-khangtictoc/test/safety_bike_s_001253.png
# Completed 490.6 KiB/544.6 KiB (46.6 KiB/s) with 20 file(s) remaining
# Completed 493.4 KiB/544.6 KiB (46.5 KiB/s) with 20 file(s) remaining
# upload: dataset\test\safety_bike_s_001481.png to s3://project02-khangtictoc/test/safety_bike_s_001481.png
# Completed 493.4 KiB/544.6 KiB (46.5 KiB/s) with 19 file(s) remaining
# Completed 496.1 KiB/544.6 KiB (46.4 KiB/s) with 19 file(s) remaining
# upload: dataset\test\trail_bike_s_000073.png to s3://project02-khangtictoc/test/trail_bike_s_000073.png
# Completed 496.1 KiB/544.6 KiB (46.4 KiB/s) with 18 file(s) remaining
# Completed 498.8 KiB/544.6 KiB (46.6 KiB/s) with 18 file(s) remaining
# upload: dataset\test\safety_bike_s_001690.png to s3://project02-khangtictoc/test/safety_bike_s_001690.png
# Completed 498.8 KiB/544.6 KiB (46.6 KiB/s) with 17 file(s) remaining
# Completed 501.7 KiB/544.6 KiB (46.6 KiB/s) with 17 file(s) remaining
# upload: dataset\test\velocipede_s_000001.png to s3://project02-khangtictoc/test/velocipede_s_000001.png
# Completed 501.7 KiB/544.6 KiB (46.6 KiB/s) with 16 file(s) remaining
# Completed 504.5 KiB/544.6 KiB (46.4 KiB/s) with 16 file(s) remaining
# upload: dataset\test\velocipede_s_000292.png to s3://project02-khangtictoc/test/velocipede_s_000292.png
# Completed 504.5 KiB/544.6 KiB (46.4 KiB/s) with 15 file(s) remaining
# Completed 507.4 KiB/544.6 KiB (46.7 KiB/s) with 15 file(s) remaining
# upload: dataset\test\velocipede_s_000106.png to s3://project02-khangtictoc/test/velocipede_s_000106.png
# Completed 507.4 KiB/544.6 KiB (46.7 KiB/s) with 14 file(s) remaining
# Completed 509.5 KiB/544.6 KiB (46.7 KiB/s) with 14 file(s) remaining
# upload: dataset\test\velocipede_s_000369.png to s3://project02-khangtictoc/test/velocipede_s_000369.png
# Completed 509.5 KiB/544.6 KiB (46.7 KiB/s) with 13 file(s) remaining
# Completed 512.5 KiB/544.6 KiB (46.7 KiB/s) with 13 file(s) remaining
# upload: dataset\test\velocipede_s_000863.png to s3://project02-khangtictoc/test/velocipede_s_000863.png
# Completed 512.5 KiB/544.6 KiB (46.7 KiB/s) with 12 file(s) remaining
# Completed 514.6 KiB/544.6 KiB (46.8 KiB/s) with 12 file(s) remaining
# upload: dataset\test\velocipede_s_000041.png to s3://project02-khangtictoc/test/velocipede_s_000041.png
# Completed 514.6 KiB/544.6 KiB (46.8 KiB/s) with 11 file(s) remaining
# Completed 517.0 KiB/544.6 KiB (46.7 KiB/s) with 11 file(s) remaining
# upload: dataset\test\velocipede_s_001201.png to s3://project02-khangtictoc/test/velocipede_s_001201.png
# Completed 517.0 KiB/544.6 KiB (46.7 KiB/s) with 10 file(s) remaining
# Completed 519.7 KiB/544.6 KiB (46.6 KiB/s) with 10 file(s) remaining
# upload: dataset\test\velocipede_s_001232.png to s3://project02-khangtictoc/test/velocipede_s_001232.png
# Completed 519.7 KiB/544.6 KiB (46.6 KiB/s) with 9 file(s) remaining
# Completed 522.5 KiB/544.6 KiB (46.6 KiB/s) with 9 file(s) remaining
# upload: dataset\test\velocipede_s_001277.png to s3://project02-khangtictoc/test/velocipede_s_001277.png
# Completed 522.5 KiB/544.6 KiB (46.6 KiB/s) with 8 file(s) remaining
# Completed 525.2 KiB/544.6 KiB (46.7 KiB/s) with 8 file(s) remaining
# upload: dataset\test\velocipede_s_001335.png to s3://project02-khangtictoc/test/velocipede_s_001335.png
# Completed 525.2 KiB/544.6 KiB (46.7 KiB/s) with 7 file(s) remaining
# Completed 528.1 KiB/544.6 KiB (46.7 KiB/s) with 7 file(s) remaining
# upload: dataset\test\velocipede_s_001355.png to s3://project02-khangtictoc/test/velocipede_s_001355.png
# Completed 528.1 KiB/544.6 KiB (46.7 KiB/s) with 6 file(s) remaining
# Completed 531.1 KiB/544.6 KiB (46.6 KiB/s) with 6 file(s) remaining
# upload: dataset\test\velocipede_s_001379.png to s3://project02-khangtictoc/test/velocipede_s_001379.png
# Completed 531.1 KiB/544.6 KiB (46.6 KiB/s) with 5 file(s) remaining
# Completed 533.6 KiB/544.6 KiB (46.8 KiB/s) with 5 file(s) remaining
# upload: dataset\test\velocipede_s_001466.png to s3://project02-khangtictoc/test/velocipede_s_001466.png
# Completed 533.6 KiB/544.6 KiB (46.8 KiB/s) with 4 file(s) remaining
# Completed 536.6 KiB/544.6 KiB (46.9 KiB/s) with 4 file(s) remaining
# upload: dataset\test\velocipede_s_001633.png to s3://project02-khangtictoc/test/velocipede_s_001633.png
# Completed 536.6 KiB/544.6 KiB (46.9 KiB/s) with 3 file(s) remaining
# Completed 539.1 KiB/544.6 KiB (46.9 KiB/s) with 3 file(s) remaining
# upload: dataset\test\velocipede_s_001699.png to s3://project02-khangtictoc/test/velocipede_s_001699.png
# Completed 539.1 KiB/544.6 KiB (46.9 KiB/s) with 2 file(s) remaining
# Completed 541.8 KiB/544.6 KiB (47.0 KiB/s) with 2 file(s) remaining
# upload: dataset\test\velocipede_s_001744.png to s3://project02-khangtictoc/test/velocipede_s_001744.png
# Completed 541.8 KiB/544.6 KiB (47.0 KiB/s) with 1 file(s) remaining
# Completed 544.6 KiB/544.6 KiB (46.9 KiB/s) with 1 file(s) remaining
# upload: dataset\test\velocipede_s_001790.png to s3://project02-khangtictoc/test/velocipede_s_001790.png

# %% [markdown]
# And that's it! You can check the bucket and verify that the items were uploaded.

# %% [markdown]
# ## Model Training

# %% [markdown]
# For Image Classification, Sagemaker [also expects metadata](https://docs.aws.amazon.com/sagemaker/latest/dg/image-classification.html) e.g. in the form of TSV files with labels and filepaths. We can generate these using our Pandas DataFrames from earlier:

# %%
def to_metadata_file(df, prefix):
    df["s3_path"] = df["filenames"]
    df["labels"] = df["labels"].apply(lambda x: 0 if x==8 else 1)
    return df[["row", "labels", "s3_path"]].to_csv(
        f"{prefix}.lst", sep="\t", index=False, header=False
    )

# %%
train_lst = os.path.join(data_path, "train.lst")
test_lst = os.path.join(data_path, "test.lst")
to_metadata_file(df_train.copy(), os.path.join(data_path, "train"))
to_metadata_file(df_test.copy(), os.path.join(data_path, "test"))

# %% [markdown]
# We can also upload our manifest files:

# %%
# Upload files
boto3.Session().resource('s3').Bucket(
    bucket).Object('train.lst').upload_file(train_lst)
boto3.Session().resource('s3').Bucket(
    bucket).Object('test.lst').upload_file(test_lst)

# %% [markdown]
# Using the `bucket` and `region` info we can get the latest prebuilt container to run our training job, and define an output location on our s3 bucket for the model. Use the `image_uris` function from the SageMaker SDK to retrieve the latest `image-classification` image below:

# %%
import sagemaker
from sagemaker import image_uris

# Create a SageMaker session
session = sagemaker.Session()

# Use the image_uris function to retrieve the latest 'image-classification' image 
algo_image = image_uris.retrieve('image-classification', session.boto_region_name, version='latest')
s3_output_location = f"s3://{bucket}/models/image_model"
print("ECR Model Image URI: {}".format(algo_image))
print("S3 Model Output Location: {}".format(s3_output_location))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# ECR Model Image URI: 811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1
# S3 Model Output Location: s3://project02-khangtictoc/models/image_model

# %% [markdown]
# We're ready to create an estimator! Create an estimator `img_classifier_model` that uses one instance of `ml.p3.2xlarge`. Ensure that y ou use the output location we defined above - we'll be referring to that later!

# %%
from sagemaker.estimator import Estimator

img_classifier_model=Estimator(
    image_uri=algo_image,
    role=role,
    instance_count=1,
    instance_type='ml.p3.2xlarge',
    volume_size=50,
    max_run=3600,
    input_mode='File',
    output_path=s3_output_location,
    sagemaker_session=session
)

# %% [markdown]
# We can also set a few key hyperparameters and define the inputs for our model:

# %%
# Reference: https://docs.aws.amazon.com/sagemaker/latest/dg/IC-Hyperparameter.html
img_classifier_model.set_hyperparameters(
    image_shape='3,32,32',
    num_classes=2,
    num_training_samples=5000, ### TODO ### (total number of images uploaded * train_split_percentage) (1000 * 0.75)
    learning_rate=0.1,
    mini_batch_size=25,
    epochs=30,
    early_stopping=True
)

# %% [markdown]
# The `image-classification` image uses four input channels with very specific input parameters. For convenience, we've provided them below:

# %%
from sagemaker.debugger import Rule, rule_configs
from sagemaker.session import TrainingInput
model_inputs = {
        "train": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train/",
            content_type="application/x-image"
        ),
        "validation": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test/",
            content_type="application/x-image"
        ),
        "train_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/train.lst",
            content_type="application/x-image"
        ),
        "validation_lst": sagemaker.inputs.TrainingInput(
            s3_data=f"s3://{bucket}/test.lst",
            content_type="application/x-image"
        )
}

# %% [markdown]
# Great, now we can train the model using the model_inputs. In the cell below, call the `fit` method on our model,:

# %%
img_classifier_model.fit( inputs=model_inputs, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: image-classification-2024-05-02-17-13-19-821
# 2024-05-02 17:13:21 Starting - Starting the training job
# 2024-05-02 17:13:21 Pending - Training job waiting for capacity.........
# 2024-05-02 17:14:34 Pending - Preparing the instances for training...
# 2024-05-02 17:15:16 Downloading - Downloading input data...
# 2024-05-02 17:15:36 Downloading - Downloading the training image........................
# 2024-05-02 17:20:08 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Thu May  2 17:20:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.161.08             Driver Version: 535.161.08   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla V100-SXM2-16GB           On  | 00000000:00:1E.0 Off |                    0 |
# | N/A   44C    P0              27W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 535.161.08.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [05/02/2024 17:20:36 INFO 140107127228224] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/image_classification/default-input.json: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': 30, 'learning_rate': 0.1, 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': 32, 'image_shape': '3,224,224', 'precision_dtype': 'float32'}
# [05/02/2024 17:20:36 INFO 140107127228224] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'early_stopping': 'True', 'epochs': '30', 'image_shape': '3,32,32', 'learning_rate': '0.1', 'mini_batch_size': '25', 'num_classes': '2', 'num_training_samples': '5000'}
# [05/02/2024 17:20:36 INFO 140107127228224] Final configuration: {'use_pretrained_model': 0, 'num_layers': 152, 'epochs': '30', 'learning_rate': '0.1', 'lr_scheduler_factor': 0.1, 'optimizer': 'sgd', 'momentum': 0, 'weight_decay': 0.0001, 'beta_1': 0.9, 'beta_2': 0.999, 'eps': 1e-08, 'gamma': 0.9, 'mini_batch_size': '25', 'image_shape': '3,32,32', 'precision_dtype': 'float32', 'early_stopping': 'True', 'num_classes': '2', 'num_training_samples': '5000'}
# [05/02/2024 17:20:36 INFO 140107127228224] Searching for .lst files in /opt/ml/input/data/train_lst.
# [05/02/2024 17:20:36 INFO 140107127228224] Creating record files for train.lst
# [05/02/2024 17:20:36 INFO 140107127228224] Done creating record files...
# [05/02/2024 17:20:36 INFO 140107127228224] Searching for .lst files in /opt/ml/input/data/validation_lst.
# [05/02/2024 17:20:36 INFO 140107127228224] Creating record files for test.lst
# [05/02/2024 17:20:36 INFO 140107127228224] Done creating record files...
# [05/02/2024 17:20:36 INFO 140107127228224] use_pretrained_model: 0
# [05/02/2024 17:20:36 INFO 140107127228224] multi_label: 0
# [05/02/2024 17:20:36 INFO 140107127228224] Performing random weight initialization
# [05/02/2024 17:20:36 INFO 140107127228224] ---- Parameters ----
# [05/02/2024 17:20:36 INFO 140107127228224] num_layers: 152
# [05/02/2024 17:20:36 INFO 140107127228224] data type: <class 'numpy.float32'>
# [05/02/2024 17:20:36 INFO 140107127228224] epochs: 30
# [05/02/2024 17:20:36 INFO 140107127228224] optimizer: sgd
# [05/02/2024 17:20:36 INFO 140107127228224] momentum: 0.9
# [05/02/2024 17:20:36 INFO 140107127228224] weight_decay: 0.0001
# [05/02/2024 17:20:36 INFO 140107127228224] learning_rate: 0.1
# [05/02/2024 17:20:36 INFO 140107127228224] num_training_samples: 5000
# [05/02/2024 17:20:36 INFO 140107127228224] mini_batch_size: 25
# [05/02/2024 17:20:36 INFO 140107127228224] image_shape: 3,32,32
# [05/02/2024 17:35:09 INFO 140107127228224] Early stopping criteria met.
#
# 2024-05-02 17:35:32 Uploading - Uploading generated training model
# 2024-05-02 17:35:32 Completed - Training job completed
# Training seconds: 1216
# Billable seconds: 1216

# %% [markdown]
# If all goes well, you'll end up with a model topping out above `.8` validation accuracy. With only 1000 training samples in the CIFAR dataset, that's pretty good. We could definitely pursue data augmentation & gathering more samples to help us improve further, but for now let's proceed to deploy our model.
#
# ### Getting ready to deploy
#
# To begin with, let's configure Model Monitor to track our deployment. We'll define a `DataCaptureConfig` below:

# %%
from sagemaker.model_monitor import DataCaptureConfig

data_capture_config = DataCaptureConfig(
    enable_capture=True,
    sampling_percentage=100,
    destination_s3_uri=f"s3://{bucket}/data_capture"
)

# %% [markdown]
# Note the `destination_s3_uri` parameter: At the end of the project, we can explore the `data_capture` directory in S3 to find crucial data about the inputs and outputs Model Monitor has observed on our model endpoint over time.
#
# With that done, deploy your model on a single `ml.m5.xlarge` instance with the data capture config attached:

# %%
deployment = img_classifier_model.deploy(
    instance_type='ml.m5.xlarge',
    initial_instance_count=1,
    data_capture_config=data_capture_config,
    )

endpoint = deployment.endpoint_name
print(endpoint)
# Out:
# INFO:sagemaker:Creating model with name: image-classification-2024-05-02-16-03-16-221
# INFO:sagemaker:Creating endpoint-config with name image-classification-2024-05-02-16-03-16-221
# INFO:sagemaker:Creating endpoint with name image-classification-2024-05-02-16-03-16-221
# --------------!image-classification-2024-05-02-16-03-16-221

# %% [markdown]
# Note the endpoint name for later as well.
#
# Next, instantiate a Predictor:

# %%
from sagemaker.predictor import Predictor

predictor = Predictor(endpoint_name=deployment.endpoint_name)

# %% [markdown]
# In the code snippet below we are going to prepare one of your saved images for prediction. Use the predictor to process the `payload`.

# %%
from sagemaker.serializers import IdentitySerializer

predictor.serializer = IdentitySerializer("image/png")
with open(os.path.join(data_path, "test", "bicycle_s_001789.png"), "rb") as f:
    payload = f.read()

inference = deployment.predict(
    payload,
    {
        "ContentType": "application/x-image",
        "Accept": "application/json"
    }
)

# %% [markdown]
# Your `inference` object is an array of two values, the predicted probability value for each of your classes (bicycle and motorcycle respectively.) So, for example, a value of `b'[0.91, 0.09]'` indicates the probability of being a bike is 91% and being a motorcycle is 9%.

# %%
print(inference)
# Out:
# b'[0.9567974805831909, 0.04320251941680908]'

# %% [markdown]
# ### Draft Lambdas and Step Function Workflow

# %% [markdown]
# Your operations team uses Step Functions to orchestrate serverless workflows. One of the nice things about Step Functions is that [workflows can call other workflows](https://docs.aws.amazon.com/step-functions/latest/dg/connect-stepfunctions.html), so the team can easily plug your workflow into the broader production architecture for Scones Unlimited.
#
# In this next stage you're going to write and deploy three Lambda functions, and then use the Step Functions visual editor to chain them together! Our functions are going to work with a simple data object:
#
# ```python
# {
#     "inferences": [], # Output of predictor.predict
#     "s3_key": "", # Source data S3 key
#     "s3_bucket": "", # Source data S3 bucket
#     "image_data": ""  # base64 encoded string containing the image data
# }
# ```
#
# A good test object that you can use for Lambda tests and Step Function executions, throughout the next section, might look like this:
#
# ```python
# {
#   "image_data": "",
#   "s3_bucket": MY_BUCKET_NAME, # Fill in with your bucket
#   "s3_key": "test/bicycle_s_000513.png"
# }
# ```
#
# Using these fields, your functions can read and write the necessary data to execute your workflow. Let's start with the first function. Your first Lambda function will copy an object from S3, base64 encode it, and then return it to the step function as `image_data` in an event.
#
# Go to the Lambda dashboard and create a new Lambda function with a descriptive name like "serializeImageData" and select thr 'Python 3.8' runtime. Add the same permissions as the SageMaker role you created earlier. (Reminder: you do this in the Configuration tab under "Permissions"). Once you're ready, use the starter code below to craft your Lambda handler:
#
# ```python
# import json
# import boto3
# import base64
#
# s3 = boto3.client('s3')
#
# def lambda_handler(event, context):
#     """A function to serialize target data from S3"""
#
#     # Get the s3 address from the Step Function event input
#     key = ## TODO: fill in
#     bucket = ## TODO: fill in
#
#     # Download the data from s3 to /tmp/image.png
#     ## TODO: fill in
#
#     # We read the data from a file
#     with open("/tmp/image.png", "rb") as f:
#         image_data = base64.b64encode(f.read())
#
#     # Pass the data back to the Step Function
#     print("Event:", event.keys())
#     return {
#         'statusCode': 200,
#         'body': {
#             "image_data": image_data,
#             "s3_bucket": bucket,
#             "s3_key": key,
#             "inferences": []
#         }
#     }
# ```
#
# The next function is responsible for the classification part - we're going to take the image output from the previous function, decode it, and then pass inferences back to the the Step Function.
#
# Because this Lambda will have runtime dependencies (i.e. the SageMaker SDK) you'll need to package them in your function. *Key reading:* https://docs.aws.amazon.com/lambda/latest/dg/python-package-create.html#python-package-create-with-dependency

# %%
library_path = os.path.join('library', 'sagemaker')
if not os.path.exists(library_path):
    os.makedirs(library_path)

# %%
# !pip install --target ./library/python/lib/python3.8/site-packages sagemaker

# %% [markdown]
# Zip `sagemaker` folder in `library` to `sagemaker.zip`, then upload to S3

# %% [markdown]
# > File zip should be in the following format. Reference: [https://docs.aws.amazon.com/lambda/latest/dg/python-layers.html#python-layer-paths](https://docs.aws.amazon.com/lambda/latest/dg/python-layers.html#python-layer-paths)
#
# ![image.png](img/zip_file_for_lambda_layer.png)

# %%
sagemaker_lib_path = os.path.join('library', 'sagemaker.zip')
boto3.Session().resource('s3').Bucket(
    bucket).Object('python-module-library/sagemaker.zip').upload_file(sagemaker_lib_path)
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials

# %% [markdown]
# Create a new Lambda function with the same rights and a descriptive name, then fill in the starter code below for your classifier Lambda.
#
# ```python
# import json
# import sagemaker
# import base64
# from sagemaker.serializers import IdentitySerializer
#
# # Fill this in with the name of your deployed model
# ENDPOINT = ## TODO: fill in
#
# def lambda_handler(event, context):
#
#     # Decode the image data
#     image = base64.b64decode(## TODO: fill in)
#
#     # Instantiate a Predictor
#     predictor = ## TODO: fill in
#
#     # For this model the IdentitySerializer needs to be "image/png"
#     predictor.serializer = IdentitySerializer("image/png")
#
#     # Make a prediction:
#     inferences = ## TODO: fill in
#
#     # We return the data back to the Step Function
#     event["inferences"] = inferences.decode('utf-8')
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
#
# Finally, we need to filter low-confidence inferences. Define a threshold between 1.00 and 0.000 for your model: what is reasonble for you? If the model predicts at `.70` for it's highest confidence label, do we want to pass that inference along to downstream systems? Make one last Lambda function and tee up the same permissions:
#
# ```python
# import json
#
#
# THRESHOLD = .93
#
#
# def lambda_handler(event, context):
#
#     # Grab the inferences from the event
#     inferences = ## TODO: fill in
#
#     # Check if any values in our inferences are above THRESHOLD
#     meets_threshold = ## TODO: fill in
#
#     # If our threshold is met, pass our data back out of the
#     # Step Function, else, end the Step Function with an error
#     if meets_threshold:
#         pass
#     else:
#         raise("THRESHOLD_CONFIDENCE_NOT_MET")
#
#     return {
#         'statusCode': 200,
#         'body': json.dumps(event)
#     }
# ```
# Once you have tested the lambda functions, save the code for each lambda function in a python script called 'lambda.py'.
#
# With your lambdas in place, you can use the Step Functions visual editor to construct a workflow that chains them together. In the Step Functions console you'll have the option to author a Standard step function *Visually*.
#
# When the visual editor opens, you'll have many options to add transitions in your workflow. We're going to keep it simple and have just one: to invoke Lambda functions. Add three of them chained together. For each one, you'll be able to select the Lambda functions you just created in the proper order, filter inputs and outputs, and give them descriptive names.
#
# Make sure that you:
#
# 1. Are properly filtering the inputs and outputs of your invokations (e.g. `$.body`)
# 2. Take care to remove the error handling from the last function - it's supposed to "fail loudly" for your operations colleagues!
#
# Take a screenshot of your working step function in action and export the step function as JSON for your submission package.
#
# Great! Now you can use the files in `./test` as test files for our workflow. Depending on our threshold, our workflow should reliably pass predictions about images from `./test` on to downstream systems, while erroring out for inferences below our confidence threshold!

# %% [markdown]
# ### Testing and Evaluation

# %% [markdown]
# Do several step function invokations using data from the `./test` folder. This process should give you confidence that the workflow both *succeeds* AND *fails* as expected. In addition, SageMaker Model Monitor will generate recordings of your data and inferences which we can visualize.
#
# Here's a function that can help you generate test inputs for your invokations:

# %%
def generate_test_case():
    # Setup s3 in boto3
    s3 = boto3.resource('s3')

    # Randomly pick from sfn or test folders in our bucket
    objects = s3.Bucket(bucket).objects.filter(Prefix="test")
    
    # Grab any random object key from that folder!
    obj = random.choice([x.key for x in objects])

    return json.dumps({
        "image_data": "",
        "s3_bucket": bucket,
        "s3_key": obj
    })
random_json_obj = generate_test_case()
random_json_obj
# Out:
# '{"image_data": "", "s3_bucket": "project02-khangtictoc", "s3_key": "test/safety_bike_s_001481.png"}'

# %% [markdown]
# We can make a bunch of random object and execute tasks in automation way

# %%
##  (Optional)
CAPTURE_FILE_NUM = 100
random_json_obj_list = []

for i in range (CAPTURE_FILE_NUM):
    rand_obj = generate_test_case()
    random_json_obj_list.append(rand_obj)
len(random_json_obj_list)
# Out:
# 100

# %%
def retrieve_all_test_sample():
    test_sample = []

    # Setup s3 in boto3
    s3 = boto3.resource('s3')

    objects = s3.Bucket(bucket).objects.filter(Prefix="test/")

    for obj in objects:
        obj_json = json.dumps({
            "image_data": "",
            "s3_bucket": bucket,
            "s3_key": obj.key
        })

        test_sample.append(obj_json)

    return test_sample

# %%
test_json_obj_list = retrieve_all_test_sample()
len(test_json_obj_list)
# Out:
# 200

# %% [markdown]
# Execute State Machine with list of test objects

# %%
# Create a client for the AWS Step Functions service
sfn = boto3.client('stepfunctions')

# Define the state machine ARN and input
state_machine_arn = 'arn:aws:states:us-east-1:673115746990:stateMachine:ImagePrediction_Bike_Motorbike'

# Start an execution of the state machine

for i in range(len(test_json_obj_list)):
    response = sfn.start_execution(
        stateMachineArn=state_machine_arn,
        input=test_json_obj_list[i]
    )
    print(response)
# Out:
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:1a0055ca-7c44-4f08-8e74-b63921a3d676', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 57, 465000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'da04b19d-6ff2-43b7-b967-ef042c3345ea', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'da04b19d-6ff2-43b7-b967-ef042c3345ea', 'date': 'Thu, 02 May 2024 17:09:57 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:11aa5dcc-7254-43e2-bdda-74a1f6fe4602', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 57, 783000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'a332fb3f-d34c-462b-b44e-f85da24766a2', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a332fb3f-d34c-462b-b44e-f85da24766a2', 'date': 'Thu, 02 May 2024 17:09:57 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:c7caec14-7604-43db-b6da-f2c9f3751c15', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 58, 102000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '5ad322fb-e538-4e37-8704-4ef81787321e', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '5ad322fb-e538-4e37-8704-4ef81787321e', 'date': 'Thu, 02 May 2024 17:09:58 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:fab53291-5d3e-480e-b4fd-dfdd079d474f', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 58, 437000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '1d258fc0-d7c5-48ce-b282-9cf712d5ff0f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '1d258fc0-d7c5-48ce-b282-9cf712d5ff0f', 'date': 'Thu, 02 May 2024 17:09:58 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:bf116c39-ec62-4c5e-b1a7-8bfee341cc97', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 58, 756000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '181bf5bd-bd85-4e87-ae31-859aa1915364', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '181bf5bd-bd85-4e87-ae31-859aa1915364', 'date': 'Thu, 02 May 2024 17:09:58 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:3df3ccf4-f0a6-4cd8-a2d7-01360877f2cc', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 59, 114000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '796a0978-d8a8-4300-a901-a73bca27cead', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '796a0978-d8a8-4300-a901-a73bca27cead', 'date': 'Thu, 02 May 2024 17:09:59 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:43f2194a-2fe4-49e9-85a7-1a15c1fddf48', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 59, 479000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'd4014d2c-a5dc-42f7-8866-c3608d5c92d5', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'd4014d2c-a5dc-42f7-8866-c3608d5c92d5', 'date': 'Thu, 02 May 2024 17:09:59 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:6e576543-a71a-412b-b983-c5527030d833', 'startDate': datetime.datetime(2024, 5, 3, 0, 9, 59, 802000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '32532635-e664-4a39-bf9f-d2e5b22c17be', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '32532635-e664-4a39-bf9f-d2e5b22c17be', 'date': 'Thu, 02 May 2024 17:09:59 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:0d966b5f-ec11-4db6-86f4-2748723ef8cb', 'startDate': datetime.datetime(2024, 5, 3, 0, 10, 0, 125000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId':
, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '55d28b1f-68ab-49a8-8892-4d28fac3a55c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '55d28b1f-68ab-49a8-8892-4d28fac3a55c', 'date': 'Thu, 02 May 2024 17:11:02 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '162', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:8647d61c-fcc0-4e4f-a162-39b4a1c3a743', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 2, 598000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'c5aa644f-c042-4796-834c-5d20b72081a6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'c5aa644f-c042-4796-834c-5d20b72081a6', 'date': 'Thu, 02 May 2024 17:11:02 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:4e2375a9-36e1-4f77-969a-da97756eb860', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 2, 903000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '18ca7590-ca0a-4eaf-a3da-0c8d3d4b0b02', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '18ca7590-ca0a-4eaf-a3da-0c8d3d4b0b02', 'date': 'Thu, 02 May 2024 17:11:02 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:64e1f5a6-5aa3-4bc5-abbb-222991847d39', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 3, 239000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '99ea6ac7-a584-425c-9740-d0c47fb830ea', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '99ea6ac7-a584-425c-9740-d0c47fb830ea', 'date': 'Thu, 02 May 2024 17:11:03 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:4915e342-a16e-4a2b-ae1e-44ba0cadfc1c', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 3, 581000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'bd58bff9-a02c-4c60-911a-56d4ec32e3e7', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'bd58bff9-a02c-4c60-911a-56d4ec32e3e7', 'date': 'Thu, 02 May 2024 17:11:03 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:00c00ee0-18a9-4ced-8f17-2ee89ee2d4b1', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 3, 987000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': 'a78aa752-ba79-4091-8c10-0cdf87941c78', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': 'a78aa752-ba79-4091-8c10-0cdf87941c78', 'date': 'Thu, 02 May 2024 17:11:04 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '163', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {'executionArn': 'arn:aws:states:us-east-1:673115746990:execution:ImagePrediction_Bike_Motorbike:65f35434-14be-406e-99a1-a2860f7386ff', 'startDate': datetime.datetime(2024, 5, 3, 0, 11, 4, 340000, tzinfo=tzlocal()), 'ResponseMetadata': {'RequestId': '651323e5-7b84-47c2-961d-13d3b084d973', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '651323e5-7b84-47c2-961d-13d3b084d973', 'date': 'Thu, 02 May 2024 17:11:04 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '162', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}

# %% [markdown]
# In the Step Function dashboard for your new function, you can create new executions and copy in the generated test cases. Do several executions so that you can generate data you can evaluate and visualize.
#
# Once you've done several executions, let's visualize the record of our inferences. Pull in the JSONLines data from your inferences like so:

# %%
from sagemaker.s3 import S3Downloader

# In S3 your data will be saved to a datetime-aware path
# Find a path related to a datetime you're interested in
s3_data_captured_path = "s3://project02-khangtictoc/data_capture/"

S3Downloader.download(s3_data_captured_path, "captured_data")

# Feel free to repeat this multiple times and pull in more data
# Out:
# ['captured_data\\image-classification-2024-05-02-16-03-16-221\\AllTraffic\\2024\\05\\02\\17\\01-52-391-343b6d70-f7ee-4c84-8bd3-f6770416f1c8.jsonl',
#  'captured_data\\image-classification-2024-05-02-16-03-16-221\\AllTraffic\\2024\\05\\02\\17\\03-24-264-c9645d95-5fe2-4dac-9eb9-5bfab9216c10.jsonl',
#  'captured_data\\image-classification-2024-05-02-16-03-16-221\\AllTraffic\\2024\\05\\02\\17\\10-08-228-8c9b1794-bd2a-43d2-8b29-2d0258e4f1f7.jsonl']

# %% [markdown]
# The data are in JSONLines format, where multiple valid JSON objects are stacked on top of eachother in a single `jsonl` file. We'll import an open-source library, `jsonlines` that was purpose built for parsing this format.

# %%
# !pip install jsonlines
import jsonlines
# Out:
# Requirement already satisfied: jsonlines in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (4.0.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from jsonlines) (23.2.0)

# %% [markdown]
# Now we can extract the data from each of the source files:

# %%
import os

# List the file names we downloaded
captured_data_path = "./captured_data"

json_data = []

# Dump all the data into an array
# Traverse directory recursively
for root, dirs, files in os.walk(captured_data_path):
    for file in files:
        # Check if file ends with .jsonl
        if file.endswith('.jsonl'):
            with open(os.path.join(root, file), 'r') as f:
                for line in f:
                    # Parse JSON line and append to list
                    json_data.append(json.loads(line))

# %% [markdown]
# The data should now be a list of dictionaries, with significant nesting. We'll give you an example of some code that grabs data out of the objects and visualizes it:

# %%
# Define how we'll get our data
def simple_getter(obj):
    inferences = obj["captureData"]["endpointOutput"]["data"]
    timestamp = obj["eventMetadata"]["inferenceTime"]
    return json.loads(inferences), timestamp

simple_getter(json_data[0])
# Out:
# ([0.0005281100166030228, 0.9994719624519348], '2024-05-02T17:01:52Z')

# %% [markdown]
# Finally, here's an example of a visualization you can build with this data. In this last part, you will take some time and build your own - the captured data has the input images, the resulting inferences, and the timestamps.

# %%
# Populate the data for the x and y axis
x = []
y = []
for obj in json_data:
    inference, timestamp = simple_getter(obj)

    y.append(max(inference))
    x.append(timestamp)

# Todo: here is an visualization example, take some time to build another visual that helps monitor the result
# Plot the data
plt.scatter(x, y, c=['r' if k<.94 else 'b' for k in y ])
plt.axhline(y=0.94, color='g', linestyle='--')
plt.ylim(bottom=.88)

# Add labels
plt.ylabel("Confidence")
plt.suptitle("Observed Recent Inferences", size=14)
plt.title("Pictured with confidence threshold for production use", size=10)

# Give it some pizzaz!
plt.style.use("Solarize_Light2")
plt.gcf().autofmt_xdate()
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# ### Todo: build your own visualization

# %% [markdown]
# ### Congratulations!
#
# You've reached the end of the project. In this project you created an event-drivent ML workflow that can be incorporated into the Scones Unlimited production architecture. You used the SageMaker Estimator API to deploy your SageMaker Model and Endpoint, and you used AWS Lambda and Step Functions to orchestrate your ML workflow. Using SageMaker Model Monitor, you instrumented and observed your Endpoint, and at the end of the project you built a visualization to help stakeholders understand the performance of the Endpoint over time. If you're up for it, you can even go further with these stretch goals:
#
# * Extend your workflow to incorporate more classes: the CIFAR dataset includes other vehicles that Scones Unlimited can identify with this model.
# * Modify your event driven workflow: can you rewrite your Lambda functions so that the workflow can process multiple image inputs in parallel? Can the Step Function "fan out" to accomodate this new workflow?
# * Consider the test data generator we provided for you. Can we use it to create a "dummy data" generator, to simulate a continuous stream of input data? Or a big paralell load of data?
# * What if we want to get notified every time our step function errors out? Can we use the Step Functions visual editor in conjunction with a service like SNS to accomplish this? Try it out!
